# %% [markdown]
# # 1.데이터불러오기

# %% [markdown]
# # 개선해야할 점
#     1) title+content 형태소 분석 & word2vec
#     2) [사진,포토] 등 불필요한 단어 제거,한자제거,
#
#     3) 불용어처리 가능하게 하기

# %%
import re
import pandas as pd
import numpy as np
import json
#from bs4 import Beautiful Soup
# from nltk.corpus import Beautiful Soup
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer
import konlp
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#헤더추가 (title,content,time)
train =pd.read_csv('dataset3000.csv',names=['title','content','time','nan'])
train.head()
train.shape
train.dtypes
# Out:
# title       object
# content     object
# time        object
# nan        float64
# dtype: object

# %%
train.head()
# Out:
#                                       title  \
# 0                 '[사진]조여정,'우아한 플라워원피스 입고''
# 1              '[프로필]국세청 과장급 전보자(7월 22일 자)'
# 2           '[조이HD]춘사영화제 참석한 봉준호 감독-한진원 작가'
# 3                 '[사진]클라라,'시선 올킬 블루 롱드레스''
# 4  '[사진]7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''
#
#                                              content              time  nan
# 0  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40  NaN
# 1  '조사기획1계장 ▲경주세무서장 ▲국세청 인도네시아 주재관 ▲외교부 파견 ▲서울지방국...  2019-07-20 16:40  NaN
# 2  '말레이시아 Finas(말레시아 영화진흥위)의 신임 대표인 Ahmad Idham을 ...  2019-07-20 16:40  NaN
# 3  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40  NaN
# 4  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40  NaN

# %%
# nan 변수버리기
train.drop(['nan'], axis='columns', inplace=True)

# %%
train.tail()
# Out:
#                                             title  \
# 2868  '[포토] ABCC FINTECH INDONESIA, 양해각서(MOU) 체결'
# 2869                        '옥천 복숭아, 홍콩 시장 공략 나서'
# 2870    '‘애인과 혼전 성관계’ 때문에 어느 20대 여성이 받은 무시무시한 처벌'
# 2871         '부산대병원 개발 '의료영상저장전송시스템', 카자흐스탄서 맹활약'
# 2872          'aT 인도네시아서 K-Food 2,235만불 수출상담등 쾌거'
#
#                                                 content              time
# 2868  '시사매거진, SISAMAGAZINE 8월 1일 오후 4시(현지시간) 인도네시아 자...  2019-08-01 20:00
# 2869  '한편, 옥천군복숭아수출협의회는 2017년 인도네시아에 0.7t(4천522달러), ...  2019-08-01 20:00
# 2870  '혼전 성관계를 가진 인도네시아 남녀가 공개 태형을 당했다고 서울신문 나우뉴스가 1...  2019-08-01 20:00
# 2871  '세계 시장에서 경쟁할 수 있는 수준의 '엔터프라이즈 데이터 플랫폼' 개발을 위해 ...  2019-08-01 20:00
# 2872  '인도네시아에서 '2019 자카르타 K-Food Fair' 행사를 개최해 총 2천2...  2019-08-01 20:00

# %%
train.shape
# Out:
# (2873, 3)

# %% [markdown]
# # 2.데이터전처리

# %%
 # 데이터개수
 print('학습 데이터의 개수: {}'.format(len(train)))
# Out:
# 학습 데이터의 개수: 2873

# %%
# title(제목) 컬럼 문자길이
train_title_len=train['title'].apply(len)
train_title_len.head()
# Out:
# 0    25
# 1    28
# 2    31
# 3    25
# 4    40
# Name: title, dtype: int64

# %%
# content(내용) 컬럼 문자길이
train_content_len=train['content'].apply(len)
train_content_len.head()
# Out:
# 0    127
# 1    115
# 2    129
# 3    127
# 4    127
# Name: content, dtype: int64

# %%
# title 문자길이 분포

#그래프에 대한 이미지 크기 선언
#figsize : (가로,세로) 형태의 튜플로 입력
plt.figure(figsize=(12,5))
#히스토그램 선언
# bins: 히스토그램 값에 대한 버킷 범위
# range: x축 값의 범위
# alpha: 그래프 색상 투명도
# color :그래프 색상
# label: 그래프에 대한 라벨
plt.hist(train_title_len, bins=100, alpha=0.5, color='b',label='word')
plt.yscale('log',nonposy='clip')
#그래프 제목
plt.title('Log-histogram of length of review')
#그래프 x축 라벨
plt.xlabel('Length of review')
#그래프 y축 라벨
plt.ylabel('Number of review')
# Out:
# Text(0, 0.5, 'Number of review')

# %%
# title 길이 통계값
print('제목 길이 최댓값: {}'.format(np.max(train_title_len)))
print('제목 길이 최솟값: {}'.format(np.min(train_title_len)))
print('제목 길이 평균값: {:.2f}'.format(np.mean(train_title_len)))
print('제목 길이 표준편차: {:.2f}'.format(np.std(train_title_len)))
print('제목 길이 중간값 {}'.format(np.median(train_title_len)))
print('제목 길이 제1사분위: {}'.format(np.percentile(train_title_len,25)))
print('제목 길이 제3사분위: {}'.format(np.percentile(train_title_len,75)))
# Out:
# 제목 길이 최댓값: 62
# 제목 길이 최솟값: 4
# 제목 길이 평균값: 32.98
# 제목 길이 표준편차: 8.47
# 제목 길이 중간값 33.0
# 제목 길이 제1사분위: 27.0
# 제목 길이 제3사분위: 38.0

# %%
# content 문자길이 분포
# title 문자길이 분포

#그래프에 대한 이미지 크기 선언
#figsize : (가로,세로) 형태의 튜플로 입력
plt.figure(figsize=(12,5))
#히스토그램 선언
# bins: 히스토그램 값에 대한 버킷 범위
# range: x축 값의 범위
# alpha: 그래프 색상 투명도
# color :그래프 색상
# label: 그래프에 대한 라벨
plt.hist(train_content_len, bins=100, alpha=0.5, color='b',label='word')
plt.yscale('log',nonposy='clip')
#그래프 제목
plt.title('Log-histogram of length of review')
#그래프 x축 라벨
plt.xlabel('Length of review')
#그래프 y축 라벨
plt.ylabel('Number of review')
# Out:
# Text(0, 0.5, 'Number of review')

# %%
# content 길이 통계값
print('내용 길이 최댓값: {}'.format(np.max(train_content_len)))
print('내용 길이 최솟값: {}'.format(np.min(train_content_len)))
print('내용 길이 평균값: {:.2f}'.format(np.mean(train_content_len)))
print('내용 길이 표준편차: {:.2f}'.format(np.std(train_content_len)))
print('내용 길이 중간값 {}'.format(np.median(train_content_len)))
print('내용 길이 제1사분위: {}'.format(np.percentile(train_content_len,25)))
print('내용 길이 제3사분위: {}'.format(np.percentile(train_content_len,75)))
# Out:
# 내용 길이 최댓값: 177
# 내용 길이 최솟값: 12
# 내용 길이 평균값: 124.67
# 내용 길이 표준편차: 10.98
# 내용 길이 중간값 124.0
# 내용 길이 제1사분위: 120.0
# 내용 길이 제3사분위: 129.0

# %%
#wordcloud
# title(제목) 많이 사용된 단어
from wordcloud import WordCloud
cloud=WordCloud(width=800,height=600,font_path='C:/Users/glass/Downloads/gulim.ttc').generate(" ".join(train['title']))
plt.figure(figsize=(20,15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %%
tokens = [j for i in train['title'] for j in i]


import nltk

text = nltk.Text(tokens) 


import matplotlib.pyplot as plt
from matplotlib import font_manager, rc 
from matplotlib import font_manager, rc

font_fname = 'C:/Users/glass/Downloads/gulim.ttc'     # A font of your choice

font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)


fig = plt.figure()
fig.set_label('test')
plt.figure(figsize=(20, 10)) 
text.plot(50)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-bfded7d8e4ef> in <module>
#      13 font_fname = 'C:/Users/glass/Downloads/gulim.ttc'     # A font of your choice
#      14
# ---> 15 font_name = font_manager.FontProperties(fname=font_fname).get_name()
#      16 rc('font', family=font_name)
#      17
#
# ~\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     645         Return the name of the font that best matches the font properties.
#     646         """
# --> 647         return get_font(findfont(self)).family_name
#     648
#     649     def get_style(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1289     if hinting_factor is None:
#    1290         hinting_factor = rcParams['text.hinting_factor']
# -> 1291     return _get_font(filename, hinting_factor)
#    1292
#    1293
#
# RuntimeError: In FT2Font: Can not load face.  Unknown file format.

# %% [markdown]
# # 3.데이터정제
# ###  여기서는 'title'로 했다.

# %% [markdown]
# # konlpy 사용하기! #다운 필요jype

# %% [markdown]
# # [사진], [포토] 지우기!

# %%
train.head()
# Out:
#                                       title  \
# 0                 '[사진]조여정,'우아한 플라워원피스 입고''
# 1              '[프로필]국세청 과장급 전보자(7월 22일 자)'
# 2           '[조이HD]춘사영화제 참석한 봉준호 감독-한진원 작가'
# 3                 '[사진]클라라,'시선 올킬 블루 롱드레스''
# 4  '[사진]7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''
#
#                                              content              time
# 0  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40
# 1  '조사기획1계장 ▲경주세무서장 ▲국세청 인도네시아 주재관 ▲외교부 파견 ▲서울지방국...  2019-07-20 16:40
# 2  '말레이시아 Finas(말레시아 영화진흥위)의 신임 대표인 Ahmad Idham을 ...  2019-07-20 16:40
# 3  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40
# 4  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40

# %%
title=list(train['title'])

# %%
from konlpy.tag import Okt

# %%
train.dtypes
# Out:
# title      object
# content    object
# time       object
# dtype: object

# %%
train1=train

# %%
# 여기서 train을 str로 선언하면 나중에 for문을 쓰지 못한다.

# %%
#전체제목
# 리스트전체가 아니라 하나씩 빼서 처리해야하기 때문에 for문으로 처리.
#1.한글 및 공백을 제외한 문자를 모두 제거
for i in range(len(title)) :
    title[i] = re.sub("[^가-힣ㄱ-ㅎ ㅏ-ㅣ\\s]","", title[i])

print(title)
# Out:
�아티스트 낸시랭   글로벌아트페어 싱가포르서 스칼렛', '서울맛집의 새로운 기준 남다른감자탕 이정열 대표의 맛집 철학이야기', '바다 경치와 함께 힐링하는 클럽메드 빈탄 아일랜드 스파', '온갖 액티비티의 천국 클럽메드 빈탄 아일랜드', '클럽메드에서만 볼 수 있는 것 쇼', '더 레지던스 빈탄 스페셜티 레스토랑 리차리차', '인도네시아 미식 내가 만들면 맛도 두배', '팔아야 귀국 블락비 유권 손짓 한 번에 팝업스토어 들썩', '이승현 점한국 존스컵 국제농구서 일본 제압', '  지역 산업 지지하고자 동남아시아 시장에 진출', '인도네시아 년 전기차 생산 시작 토요타현대차도 관심 \xa0', '블랙핑크 제니 잠자는 숲속의 공주 같네살아있는 인형 비주얼', '방탄소년단 뷔 배려와 가족 사랑의 아이콘 해외 매체들 극찬 역시 굿보이', '쉘그룹 제로  공급', '부산 다대포송정사하 서핑스팟에서 즐기는 짜릿한 서핑 서프버디 그', ' 치킨프랜차이즈 닭껍데기 열풍에 합류', ' 몰고 빈탄섬 질주해보세요', '비치발리볼 화보 거기서 뭐 하세요', '비치발리볼 화보 받아라 강스파이크', '데뷔 년 월 히트곡 뚜두뚜두 뮤직비디오가 팝', '인도네시아어 년 월 일 오늘의 외국어 한마디는', '해외 매체들 방탄소년단 뷔 배려와 가족 사랑의 아이콘 극찬', '뚜두뚜두 이들은 지난해 월 서울을 시작으로', '오늘의 채널유권 손님맞이 나서자 팬미팅 방불', '알맹이는 가라 닭껍질부터 귤껍질까지 껍데기 전성시대', '뚜두뚜두 블랙핑크  ...

# %%
#전체 형태소나누기
#불용어 제거하기 위해 문장 단어 나누기
okt=Okt() 
title_text=[ ] # or title_text=[''] * len(title)
for i in range(len(title)) :
    title_text.append(okt.morphs(title[i],stem=True))

print(title_text[:10])
# Out:
# [['사진', '조여정', '우아하다', '플라워', '원피스', '입다'], ['프로필', '국세청', '과장', '급', '전보', '자월', '일', '자'], ['조', '이춘사', '영화제', '참석', '한', '봉준호', '감독', '한', '진원', '작가'], ['사진', '클라라', '시선', '올킬', '블루', '롱', '드레스'], ['사진', '개', '부문', '노미네이트', '기생충', '봉준호', '감독', '엄청나다', '환호', '받다'], ['사진', '함소원', '우아하다', '입장'], ['조이', '엄태구', '지적', '인', '남자', '야'], ['조이진', '기주', '매력', '적', '인', '미모'], ['조이', '기생충', '이정은', '엄마', '미소'], ['조이', '공명', '추다', '영화제', '빛', '내다', '미소']]

# %%
# 불용어제거
stop_words=['우아하다']
#clean_title=[token for w in title_text if not token in stop_words]
#print(clean_title[:10])'
result=[]
for w in title_text:
    if w not in stop_words:
        result.append(w)
        
print (result )
# Out:
# []

# %%
test = []
stop_words=['우아하다']
for i in range(len(title_text)):
    j = 0
    while(j < len(title_text[i])):
        if(title_text[i][j] in stop_words):
            title_text[i].remove(title_text[i][j])
            continue
        j += 1
    test.append(title_text[i])

print(test)
# Out:
# [['사진', '조여정', '원피스', '입다'], ['프로필', '국세청', '과장', '급', '전보', '자월', '일', '자'], ['조', '이춘사', '영화제', '참석', '봉준호', '감독', '진원', '작가'], ['사진', '클라라', '시선', '올킬', '블루', '롱', '드레스'], ['사진', '개', '부문', '노미네이트', '기생충', '봉준호', '감독', '엄청나다', '환호', '받다'], ['사진', '함소원', '입장'], ['조이', '엄태구', '지적', '인', '남자', '야'], ['조이진', '기주', '매력', '적', '인', '미모'], ['조이', '기생충', '이정은', '엄마', '미소'], ['조이', '공명', '추다', '영화제', '빛', '내다', '미소'], ['조', '이춘사', '영화제', '조여정', '칸', '이', '반한', '미소'], ['조', '이춘사', '영화제', '문지', '인', '민트', '여신'], ['사진', '공명', '훈남', '매력'], ['무역', '위', '전기', '프라이팬', '특허권', '침해', '불공정', '무역', '행위', '조사', '개시'], ['사진', '베이비페이스', '이성경', '화려하다', '변신'], ['사진', '클라라', '섹시하다'], ['사진', '상체', '노출', '클라라', '이', '보다', '더', '아찔하다', '수', '없다'], ['조이조', '여정', '추다', '영화제', '여우주연상', '에', '빛나다', '자태'], ['조이', '함소원', '연하', '남편', '을', '향', '한', '마음'], ['사진', '추다', '영화제', '참석', '한', '기생충', '봉준호', '감독'], ['사진', '이정은', '영화', '팬', '여러분', '사랑', '하다'], ['사진', '문', '지인', '섹시', '레드', '립'], ['사진', '하지영', '어느덧다', '여배우'], ['사진', '김강현', '추다', '영화제', '오다'], ['사', '진공', '명', '달콤하다', '하트'], ['조', '이전', '여', '빈', '블랙', '드레스'], ['조', '이전', '여', '빈', '추다', '영화제', '가', '주목', '하다', '신예'], ['사', '진공', '명', '젠틀', '하', '게'], ['조이', '문', '지인', '년차', '베테', '랑', '여배우'], ['사진전', '여', '빈', '아름답다', '미소'], ['조', '이춘사', '영화제', '이성경', '금빛', '몸매'], ['조이', '클라라', '보기', '만', '해도', '시원하다', '블루', '드레스'], ['사진', '정애연', '단아', '한', '매력'], ['사진', '정애연', '추다', '영화제', '레드카펫', '밟다'], ['사진', '주지훈', '그', '만의', '시그널'], ['사진', '주지훈', '럭셔리', '하', '게'], ['사진', '주지훈', '오늘', '도', '멋지다', '폭발'], ['사진', '기생충', '박명', '훈춘', '사', '영화제', '수상', '기대하다'], ['사진', '한', '진원', '작가', '봉준호', '감독', '기생충', '초대', '받다'], ['사진', '골드', '드레스', '이성경', '귀걸이', '도', '금빛', '하트'], ['사진', '레드카펫', '런웨이', '이성경', '모델', '은', '달라', '도', '달라'], ['사진', '이성경', '금빛', '각선미'], ['사진', '조여정', '미모', '여전하다'], ['사진', '조여정', '아기', '같다', '미소'], ['사진', '조여정', '미소', '여신'], ['사진', '꽃', '보다', '더', '빛나다', '조여정', '의', '미모'], ['사진', '미소', '가', '아름답다', '조여정'], ['중기', '해외진출', '지원', '발', '벗다', '나선', '부산', '경진', '원', '창조', '혁신', '센터'], ['오', '쎄다', '명불허전', '클라라', '명품', '콜라', '병', '몸매', '시선집중'], ['공사', '첨단', '환경기술', '눈', '도장'], ['경영', '대표팀', '메인', '풀', '서', '첫', '훈련', '메달', '노리다', '김서영', '컨디션', '이상', '무'], ['김주희', '무용가', '두리안', '먹방', '맛있다', '다', '채', '로운', '매력', '캄보디아', '여행'], ['경북', '중소기업', '수출', '지원', '러시아', '인니', '에', '교두보'], ['이철우', '경북', '도지사', '변하다', '산다', '도정', '의', '국제', '경쟁력', '강화', '에', '새', '바람'], ['방송', '세계', '테마', '기행', '여름날', '의', '꿈', '캄보디아', '부', '춤추다', '바다'], ['세계', '테마', '기행', '캄폿', '코롱', '산', '로엠', '거치다', '프놈펜', '으로', '김주희', '굿바이', '캄'], ['수출', '규제', '악재', '신', '남방', '시장', '이', '돌파구'], ['전', '주', '기', '접', '놀이', '인도네시아', '토라', '자', '페스티벌', '초청', '공연'], ['세계', '테마', '기행', '무용가', '김주희', '와', '함께', '캄보디아', '춤추다', '바다', '여정'], ['인도네시아어', '년', '월', '일', '오늘', '의', '외국어', '한마디', '는'], ['이', '시각', '세계', '기내식', '메뉴판', '잘못', '올리다', '감옥', '행', '위기'], ['최초', '제안', '가점', '확대', '로', '민간', '제안', '활성화', '하다'], ['전은영', '글로벌', '아트', '홀', '대표이사'], ['진범', '치밀하다', '구성', '과', '긴장감', '넘치다', '스토리'], ['신봉선', '공개', '되다', '사진', '속', '신봉선', '은', '김', '이'], ['역사', '속', '오늘', '월', '일', '임오군란', '이', '발생', '하다'], ['공사', '한국', '의', '필', '환경', '기술', '인도네시아', '에서', '호평'], ['대구', '경북', '블루', '오션', '할랄', '시장', '재', '조준'], ['이정현', '득점', '한국', '존스', '컵', '캐나다', '대파'], ['인니', '대사관', '에만', '있다', '임무', '관', '남한', '면적', '배', '가', '산림'], ['정신', '건강', '은', '우리', '가', '챙기다', '드리다'], ['산림청', '해외', '산림', '탄소배출권', '사업', '소개'], ['보잉', '맥스', '운항', '금지', '로', '분기', '에', '조천억원', '대', '타격'], ['유종', '의', '밉다', '거두다', '산림', '인', '윤영균', '산림', '복지', '진흥', '원', '원장'], ['명', '리학', '으로', '보다', '세상', '재벌', '처럼', '성공하다', '자다', '죽다', '게', '숙제', '인', '사람'], ['아스', '트', '과', '엠브라에르', '수주', '계약', '체결', '로', '실적', '증진', '기대'], ['푸드', '빌다', '중국', '철수', '대신', '뚜레쥬르', '에', '힘', '주다', '이유', '는'], ['커피', '만화경', '커피', '에게', '평화', '가', '있다'], ['인니', '기내식', '손글씨', '메뉴판', '논란', '사진', '올리다', '승객', '은', '명예훼손', '피소'], ['뉴스', '딱', '아기', '상어', '뚜', '루루', '뚜루', '동요', '로', '노숙자', '쫓아내다'], ['부산시', '인도네시아', '산업', '기', '계전', '참가',  ...

# %% [markdown]
# ## 전처리과정 전체 적용 함수

# %%
def preprocessing(train,okt,remove_stopwords=False,stop_words=[]):
    #train: 전처리할 텍스트
    #okt:okt 객체를 반복적으로 생성하지 않고 미리 생성한 후 인자로 받는다.
    #remove_stopword:불용어를 제거할지 여부 선택, 기본값은 False
    #stop_word:불용어 사전은 사용자가 직접입력해야함. 기본값은 빈 리스트
    
    #1.한글 및 공백을 제외한 문자를 모두 제거
    title_text=re.sub("[^가-힣ㄱ-ㅎ ㅏ-ㅣ\\s]","",str(train['title']))
    
    #2. okt객체를 활용해 형태소 단위로 나눈다.
    title_text=okt.morphs(str(title_text),stem=True)
    
    if remove_stopwords:
        #불용어 제거(선택적)
        title_text=[token for token in title_text if not token in stop_words]
    
    return title_text

# %%
print(title_text)def preprocessing(train,okt,remove_stopwords=False,stop_words=[]):
    #train: 전처리할 텍스트
    #okt:okt 객체를 반복적으로 생성하지 않고 미리 생성한 후 인자로 받는다.
    #remove_stopword:불용어를 제거할지 여부 선택, 기본값은 False
    #stop_word:불용어 사전은 사용자가 직접입력해야함. 기본값은 빈 리스트
    
    #1.한글 및 공백을 제외한 문자를 모두 제거
    title_text=re.sub("[^가-힣ㄱ-ㅎ ㅏ-ㅣ\\s]","",str(train['title']))
    
    #2. okt객체를 활용해 형태소 단위로 나눈다.
    title_text=okt.morphs(str(title_text),stem=True)
    
    if remove_stopwords:
        #불용어 제거(선택적)
        title_text=[token for token in title_text if not token in stop_words]
    
    return title_text

# %%
# 함수실행

# 불용어정의
stop_words=['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한','및','듯','료']

okt=Okt()

clean_train_title=[]

## 여기서 train 무엇인지... 다시 보기 p.224
for train in train['title']:
    #비어있는 데이터에서 멈추지 않도록 문자열인 경우에만 진행
    if type(train) == str:
        clean_train_title.append(preprocessing(train,okt,remove_stopwords=True,stop_words=stop_words))
    else:
        clean_train_title.append([]) # string이 아니면 비어있는 값 추가
        
clean_train_title[:4] #앞의 4개 데이터확인

# %% [markdown]
# # train1

# %%
train.head()

# %%
# train1

# 함수실행
# 불용어정의
stop_words=['은','는','이','가','하','아','것','들','의','있','되','수','보','주','등','한','및','듯','료']

okt=Okt()

clean_train_title=[]

## 여기서 train 무엇인지... 다시 보기 p.224
for train1 in train1['title']:
    #비어있는 데이터에서 멈추지 않도록 문자열인 경우에만 진행
    if type(train) == str:
        clean_train_title.append(preprocessing(train1,okt,remove_stopwords=True,stop_words=stop_words))
    else:
        clean_train_title.append([]) # string이 아니면 비어있는 값 추가
        
clean_train_title[:4] #앞의 4개 데이터확인

# %%
# 불용어 .txt 파일로 적용
def tokenize_new(doc):
    x = [line.rstrip('\n') for line in open('C:/Users/DongA2/Final_Final_Disertation/File/new_stop.txt', 'r', encoding='utf-8')]
    word_tokens = tagger.nouns(doc)
    result = [] 
    
    for w in word_tokens: 
        if w not in x: 
            
            result.append(w) 
    return result

# %%
# content 전체전처리 #return word_

# %%
# 단어최대길이설정

# %%
# 벡터표상화

# %% [markdown]
# # 4.word2vec 벡터화

# %%
#word2vec 파라미터 설명
# workers =프로세스개수
# size= 워드 벡터 특징값수(벡터의 차원을 정한다.)
# min_count =단어에 대한 최소 빈도수(적은 빈도수의 단어는 학습하지 않는다. )
# window =컨테스트 윈도우 크기
# sample=샘플링 비율 (Ex)1e-3 :0.001이 좋은 성능을 낸다

num_workers=4
num_size=300
min_word_count=40
context=10
downsampling=1e-3

# %%
#진행상황확인위해
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',level=logging.INFO)

# %%
from gensim.models import Word2Vec
print("Training model...")
model= Word2Vec(title_text, size=300, window=5, min_count=5, workers=4, sg=1)

# %%
model.most_similar("감", topn=10)

# %%
model.most_similar("사전", topn=10)

# %%
model.most_similar("설립", topn=10)

# %%
model.most_similar("사진", topn=10)

# %%
#위에 껄로 학습완료

#모델 하이퍼파라미터를 설정한 내용을 모델 이름에 담는 다면 나중에 참고하기에 좋을 것이다.
#모델을 저장하면 Word2Vec.load()를 통해 모델을 다시 사용할 수 있다. 
#model_name="300features_40minwords_10context"
############ model.save(model_name)

# %% [markdown]
# # 5. 텍스트 유사도
