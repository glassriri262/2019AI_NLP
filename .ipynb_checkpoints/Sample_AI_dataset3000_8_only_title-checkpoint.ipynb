# %% [markdown]
# # 개선해야할 점
#
#     1) 한자제거
#     2) [사진,포토] 등 불필요한 단어 제거  OK
#     3) 단어분포도(word distribution)
#     4) 불용어처리 가능하게 하기
#     5) 텍스트유사도 분석                  OK
#     6) 유사도 붙이기                      OK
#     7) 유사도 60%넘는거 삭제              OK
#     8) 0점처리-건우오빠한테 물어보기

# %% [markdown]
# # 1.데이터 로드 (Data Load)

# %%
import re
import pandas as pd
import numpy as np
import json
#from bs4 import Beautiful Soup
# from nltk.corpus import Beautiful Soup
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer
import konlp
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#헤더추가 (title,content,time)
train =pd.read_csv('dataset3000.csv',names=['title','content','time','nan'])
train.head()
train.shape
train.dtypes
# Out:
# title       object
# content     object
# time        object
# nan        float64
# dtype: object

# %%
# nan 변수버리기
train.drop(['nan'], axis='columns', inplace=True)

# %%
train.head()
# Out:
#                                       title  \
# 0                 '[사진]조여정,'우아한 플라워원피스 입고''
# 1              '[프로필]국세청 과장급 전보자(7월 22일 자)'
# 2           '[조이HD]춘사영화제 참석한 봉준호 감독-한진원 작가'
# 3                 '[사진]클라라,'시선 올킬 블루 롱드레스''
# 4  '[사진]7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''
#
#                                              content              time
# 0  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40
# 1  '조사기획1계장 ▲경주세무서장 ▲국세청 인도네시아 주재관 ▲외교부 파견 ▲서울지방국...  2019-07-20 16:40
# 2  '말레이시아 Finas(말레시아 영화진흥위)의 신임 대표인 Ahmad Idham을 ...  2019-07-20 16:40
# 3  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40
# 4  '제24회 춘사영화제는 ‘아시아를 대표하는 영화제로의 도약’을 표방한 제23회에 이...  2019-07-20 16:40

# %% [markdown]
# ## 1) [   ] 안에 있는 단어 제거

# %%
train["title"] = train["title"].str.replace("\[(.*?)\]", "") # [ ] 안에 잇는 단어 없애기

# %%
# https://regexr.com/  #정규표현식 테스트 사이트

# %%
train["title"]
# Out:
# 0                                   '조여정,'우아한 플라워원피스 입고''
# 1                                 '국세청 과장급 전보자(7월 22일 자)'
# 2                               '춘사영화제 참석한 봉준호 감독-한진원 작가'
# 3                                   '클라라,'시선 올킬 블루 롱드레스''
# 4                    '7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''
# 5                                          '함소원,'우아한 입장''
# 6                                         '엄태구, 지적인 남자야~'
# 7                                          '진기주, 매력적인 미모'
# 8                                     ''기생충' 이정은, 엄마 미소~'
# 9                                     '공명, 춘사영화제 빛내는 미소~'
# 10                               ''춘사영화제' 조여정, 칸이 반한 미소~'
# 11                                   ''춘사영화제' 문지인, 민트여신~'
# 12                                           '공명,'훈남 매력''
# 13                     '무역위, 전기프라이팬 특허권 침해 불공정무역행위 조사 개시'
# 14                                  '베이비페이스 이성경,'화려한 변신''
# 15                                           '클라라,'섹시하게''
# 16                           '상체 노출 클라라,'이보다 더 아찔할 수 없어''
# 17                             '조여정, 춘사영화제 여우주연상에 빛나는 자태'
# 18                                    '함소원, 연하 남편을 향한 마음'
# 19                                 '춘사영화제 참석한 기생충 봉준호 감독'
# 20                                  '이정은,'영화 팬 여러분 사랑해요''
# 21                                         '문지인,'섹시 레드립''
# 22                                        '하지영,'어느덧 여배우''
# 23                                      '김강현,'춘사영화제 왔어요''
# 24                                          '공명,'달콤한 하트''
# 25                                      '전여빈, 우아한 블랙 드레스'
# 26                                  '전여빈, 춘사영화제가 주목하는 신예'
# 27                                            '공명,'젠틀하게''
# 28                                   '문지인, 10년차 베테랑 여배우~'
# 29                                        '전여빈,'아름다운 미소''
#                               ...
# 2843                                ' 日 스라라넷, 인니 교육대와 제휴'
# 2844                       '길 한복판서 고양이 산 채로 잡아먹은 남성 '충격''
# 2845                                  '옥천 복숭아 홍콩 판촉활동 전개'
# 2846                '올해 휴가 아직이라면? 내일투어와 함께 공짜 해외여행 떠나세요!'
# 2847                 '로드FC, 블루문펀드와 ‘손잡았다’…동남아시아 사업 확대 추진'
# 2848                         '네마프 2019, 덴마크 비디오아트 특별전 개최'
# 2849               '㈜에스엘에프앤비 킹콩부대찌개, 올해의 브랜드 대상 2년 연속 수상'
# 2850                    '남자가 고양이를 산 채로…‘엽기 영상’에 인도네시아 충격'
# 2851                              '동티모르, 아세안 11번째 회원국 될까'
# 2852             '부산대병원 컨소시엄, ‘WEB-PACS 시스템’ 카자흐스탄에 첫 수출'
# 2853        ''네마프 2019', 롯데시네마 홍대입구서 '덴마크 비디오아트 특별전' 개최!'
# 2854                 'ROAD FC, 블루문펀드와 손 잡았다…동남亞 사업 확대 추진'
# 2855                            '옥천군, 복숭아 홍콩 수출 확대 판촉 추진'
# 2856                           '해외바이어 초청 수출상담회, 흥행 성공 예감'
# 2857               ''광고 찍어도 되겠어'…여자친구 엄지, 똥머리+스포티룩 완벽 소화'
# 2858                                 ' 인도네시아 대통령 만나는 손정의'
# 2859    ''혈관+폐에 좋은 음식' 부아메라' 오일 효능 및 부작용은?…\뉴기니섬 고산지...'"
# 2860                            '슈퍼주니어 규현, ‘SKF 2019’ 출격'
# 2861               '“임신한 채 고문·구타 당한 듯”…시리아 난민촌서 인니 여성 사망'
# 2862                                     ' 의열단, 항일의 불꽃 外'
# 2863                     '“파월이 또 우릴 실망시켰다”‥트럼프 맹비난(종합2보)'
# 2864                   '해외무대서 기술 뽐내는 中企… '세계 최초' 제품에 러브콜'
# 2865                    '10년여만에 美 금리인하 물꼬…\우리도 따라 내린다\"'"
# 2866                  '전남테크노파크, 전남 e-모빌리티산업 활성화 기업간담회 개최'
# 2867                        ' RF 온라인, 12년만에 인도네시아 서비스 종료'
# 2868              ' ABCC FINTECH INDONESIA, 양해각서(MOU) 체결'
# 2869                                '옥천 복숭아, 홍콩 시장 공략 나서'
# 2870            '‘애인과 혼전 성관계’ 때문에 어느 20대 여성이 받은 무시무시한 처벌'
# 2871                 '부산대병원 개발 '의료영상저장전송시스템', 카자흐스탄서 맹활약'
# 2872                  'aT 인도네시아서 K-Food 2,235만불 수출상담등 쾌거'
# Name: title, Length: 2873, dtype: object

# %% [markdown]
# # only title

# %%
title=list(train['title'])

# %%
title
# Out:
# ["'조여정,'우아한 플라워원피스 입고''",
#  "'국세청 과장급 전보자(7월 22일 자)'",
#  "'춘사영화제 참석한 봉준호 감독-한진원 작가'",
#  "'클라라,'시선 올킬 블루 롱드레스''",
#  "'7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''",
#  "'함소원,'우아한 입장''",
#  "'엄태구, 지적인 남자야~'",
#  "'진기주, 매력적인 미모'",
#  "''기생충' 이정은, 엄마 미소~'",
#  "'공명, 춘사영화제 빛내는 미소~'",
#  "''춘사영화제' 조여정, 칸이 반한 미소~'",
#  "''춘사영화제' 문지인, 민트여신~'",
#  "'공명,'훈남 매력''",
#  "'무역위, 전기프라이팬 특허권 침해 불공정무역행위 조사 개시'",
#  "'베이비페이스 이성경,'화려한 변신''",
#  "'클라라,'섹시하게''",
#  "'상체 노출 클라라,'이보다 더 아찔할 수 없어''",
#  "'조여정, 춘사영화제 여우주연상에 빛나는 자태'",
#  "'함소원, 연하 남편을 향한 마음'",
#  "'춘사영화제 참석한 기생충 봉준호 감독'",
#  "'이정은,'영화 팬 여러분 사랑해요''",
#  "'문지인,'섹시 레드립''",
#  "'하지영,'어느덧 여배우''",
#  "'김강현,'춘사영화제 왔어요''",
#  "'공명,'달콤한 하트''",
#  "'전여빈, 우아한 블랙 드레스'",
#  "'전여빈, 춘사영화제가 주목하는 신예'",
#  "'공명,'젠틀하게''",
#  "'문지인, 10년차 베테랑 여배우~'",
#  "'전여빈,'아름다운 미소''",
#  "''춘사영화제' 이성경, 금빛 몸매'",
#  "'클라라, 보기만 해도 시원한 블루 드레스'",
#  "'정애연,'단아한 매력''",
#  "'정애연,'춘사영화제 레드카펫 밟으며''",
#  "'주지훈,'그 만의 시그널''",
#  "'주지훈,'럭셔리하게''",
#  "'주지훈,'오늘도 멋짐 폭발''",
#  "'기생충 박명훈,'춘사영화제 수상 기대해요''",
#  "'한진원 작가-봉준호 감독,'기생충 초대 받았어요''",
#  "'골드 드레스 이성경,'귀걸이도 금빛 하트~''",
#  "'레드카펫 런웨이 이성경,'모델은 달라도 달라''",
#  "'이성경,'금빛 각선미''",
#  "'조여정,'미모 여전해''",
#  "'조여정,'아기 같은 미소''",
#  "'조여정,'미소 여신''",
#  "'꽃보다 더 빛나는 조여정의 미모'",
#  "'미소가 아름다운 조여정'",
#  "'중기 해외진출 지원 발벗고 나선 부산경진원·창조혁신센터'",
#  '\'명.불.허.전. 클라라..\\명품 콜라병 몸매 시선집중\\"\'"',
#  "'SL공사 첨단 환경기술 '눈도장''",
#  "'경영 대표팀, 메인풀서 첫 훈련…200m 메달 노리는 김서영 ‘컨디션 이상 무’'",
#  "'김주희 무용가, 두리안 먹방 ''맛있는데?'' 다채로운 매력!…캄보디아 여행 '...'",
#  '\'경북, 중소기업 수출 지원.. \\러시아.인니에 교두보\\"\'"',
#  "'이철우 경북도지사 ˝변해야 산다˝… 도정의 국제경쟁력 강화에 새바람'",
#  "' EBS '세계테마기행', 여름날의 꿈 캄보디아 4부. 춤추는 바다'",
#  '\'\'EBS 세계테마기행\' 캄폿, 코롱 산 로엠 거쳐 프놈펜으로…김주희 \\굿바이 캄...\'"',
#  "'日 수출규제 악재, 신남방시장이 돌파구'",
#  "'전주기접놀이, 인도네시아 토라자 페스티벌 초청 공연'",
#  "''EBS 세계테마기행' 무용가 김주희와 함께, 캄보디아 '춤추는 바다' 여정'",
#  "'인도네시아어, 2019년 07월 19일 오늘의 외국어 한마디는?'",
#  "' 기내식 메뉴판 잘못 올렸다가 '감옥행' 위기'",
#  "'“최초제안 가점 확대로 민간제안 활성화해야”'",
#  "'전은영 ㈜글로벌 JEY 아트홀 대표이사'",
#  "''진범' 치밀한 구성과 긴장감 넘치는 스토리 ...'",
#  "'‘신봉선’ 공개된 사진 속 신봉선은 김이 ...'",
#  "' 7월 19일, 임오군란이 발생하다'",
#  "'SL공사 한국의 필(必)환경 기술…인도네시아에서 호평'",
#  "'대구·경북, '블루오션' 할랄시장 재조준'",
#  "''이정현 20득점' 한국, 존스컵 캐나다 대파'",
#  '\'인니 韓대사관에만 있는 \'임무관\'…\\남한 면적 12배가 산림\\"\'"',
#  "'“정신 건강은 우리가 챙겨드릴게요”'",
#  "'산림청, REDD+ 해외 산림탄소배출권 사업 소개'",
#  '\'보잉 \\737 맥스 운항금지로 2분기에 5조7천억원대 타격\\"\'"',
#  "'유종의 미 거둔 ‘산림인’ 윤영균 산림복지진흥원 원장'",
#  "' 재벌처럼 성공하고 잘 죽는 게 숙제인 사람'",
#  "'아스트, KLM과 엠브라에르 E-Jet Ⅱ 수주 계약 체결로 실적 증진 기대'",
#  "'CJ푸드빌, 중국 철수 대신 '뚜레쥬르'에 힘 주는 이유는?'",
#  "' 커피에게 평화가 있기를'",
#  "'인니 '기내식 손글씨 메뉴판' 논란···사진 올린 승객은 명예훼손 피소'",
#  '\' \\아기 상어 뚜루루뚜루♬\\" 동요로 노숙자 쫓아낸다?\'"',
#  "'부산시, 인도네시아 산업기계전 참가 기업 모집'",
#  "'KMI, 'K·Fish Around The Globe' Vol.14 발간'",
#  "'한신단열 한희준 대표, “물욕의 가치를 버리고 기업가정신을 되살리자”'",
#  "'‘개인주의 vs 집단주의’ 뭐가 더 나을까…“둘다 장단점 있어”'",
#  "'세아상역(주), 친환경 비즈니스 도입을 통한 혁신 시너지 '기대''",
#  "'가루다항공 '손글씨 메뉴' SNS 올린 승객 명예훼손 혐의 피소'",
#  "'가루다항공 '손글씨 메뉴' SNS 올린 승객 명예훼손 피소'",
#  '\'작업복 외길 40년 새울토피아, \'티뷰크(T.BUC)\' 통해 \\꼭 필요한 곳에 반드시...\'"',
#  '\' 김서영 맞수 오하시 \\투병 중인 이케에 위해서도\\"\'"',
#  "' 홍지민 다이어트 비법은 ‘핑거루트’로 알려져...핑거루트...'",
#  "'KARA, 아시아 짐카나 대회 8월말 인제스피디움서 개최'",
#  "'다니엘기도회 협력교회 ‘섬김이’ 목사 간담회 열려'",
#  "''2019 두산 서비스 경진대회''",
#  "'<팔아야귀국 in 인도네시아> 유권 손짓 한 번에 들썩이는 팝업스토어!'",
#  "''팔아야 귀국' 인도 현지 쇼호스트로 변신..신봉선의 성공적인 먹방'",
#  "'가루다항공, '손글씨 메뉴' SNS 올린 승객과 공방 끝내(종합)'",
#  "'대한자동차경주협회, 인제스피디움서 '2019 아시아 오토 짐카나 대회' 2라운드...'",
#  "'보잉 “737 맥스 운항 중단으로 2분기 5조7000억 부담”'",
#  "'세아상역, 세아STX엔테크와 친환경 정책 협력'",
#  '\'보잉 \\737 맥스 운항금지로 7조7천억원대 타격\\"\'"',
#  "'보잉 '737 맥스' 운항 중단으로 5조7500억원 손실'",
#  '\'보잉 \\737 맥스 운항금지로 2분기에 5조7000억원대 타격\\"\'"',
#  "'<팔아야귀국 in 인도네시아> “줄을 서시오!” 메뉴와 함께 손님도 업그레이드...'",
#  "'세계대학총장단 건양대병원 방문'",
#  "'빈탄섬 세계적 골프장 잔디에서 디너 즐겨볼까'",
#  "'인도네시아 빈탄섬 북부 해변의 오아시스 '클럽메드''",
#  "'인도네시아 빈탄섬 해변 풀빌라'",
#  "'빈탄 대자연 품에서 힐링하는 휴가'",
#  "'더 레지던스 빈탄, 아이들의 천국 키즈클럽'",
#  "''경기 바로미터' 구리 가격 더 내려가나…中 수요가 줄었다'",
#  "'<팔아야 귀국 in 인도네시아> 신봉선이 말하면 빵! 빵! 현지 홈쇼핑에서 무슨...'",
#  "'더 레지던스 빈탄, 나만의 전용 수영장에서 조식을'",
#  "'빈탄 청정바다에서 패들보드 타볼까'",
#  "'첫방송 매진 '포레스트힐 그린 밸런스 클렌져', 앵콜방송 확정'",
#  "'본느 `포레스트힐 그린 밸런스 클렌져` 20일 CJ오쇼핑 앵콜 방송'",
#  "'故 김복동 할머니 '평화공원' 양산에 세워진다'",
#  "''팔아야귀국 in 인도네시아' 신봉선, 본격 영업 시작과 함께 특별한 홍보 도전'",
#  "'물리아 발리, 트래블 & 레져 USA 선정 3관왕 수상'",
#  "'한국 지능형교통시스템(ITS), 아세안 시장 진출 타진'",
#  '\'\'실트황제\' 방탄소년단 지민 위엄…\\숨만 쉬어도 실시간 트렌드 점령\\" 화제\'"',
#  "'클럽메드 빈탄에서 골프 입문해볼까'",
#  "'더 레지던스 빈탄이 자랑하는 스파 by ila'",
#  "'더 레지던스 빈탄 '더 다이닝 룸''",
#  "'팝아티스트 낸시랭, 'GAF 2019 글로벌아트페어 싱가포르'서 '스칼렛(Scarlet)...'",
#  "'서울맛집의 새로운 기준! 남다른감자탕 이정열 대표의 맛집 철학이야기!'",
#  "'바다 경치와 함께 힐링하는 클럽메드 빈탄 아일랜드 스파'",
#  "'온갖 액티비티의 천국 클럽메드 빈탄 아일랜드'",
#  "'클럽메드에서만 볼 수 있는 것, G.O쇼'",
#  "'더 레지던스 빈탄 스페셜티 레스토랑 '리차리차''",
#  "'인도네시아 미식, 내가 만들면 맛도 두배'",
#  "' 블락비 유권, 손짓 한 번에 팝업스토어 들썩'",
#  "'이승현 16점…한국, 존스컵 국제농구서 일본 제압'",
#  "' Yili, 지역 산업 지지하고자 동남아시아 시장에 진출'",
#  '\'인도네시아 \\2022년 전기차 생산 시작\\"... 토요타·현대차도 관심 \'UP\'\xa0\'"',
#  "'블랙핑크(BlackPink) 제니, '잠자는 숲속의 공주' 같네…살아있는 인형 비주얼'",
#  "'방탄소년단 뷔, 배려와 가족 사랑의 아이콘 해외 매체들 극찬 '역시 굿보이''",
#  "'쉘그룹, CO₂제로 LNG 공급'",
#  "'부산 다대포·송정·사하 '서핑스팟'에서 즐기는 짜릿한 서핑 '서프버디', 그...'",
#  "'BBQ 치킨프랜차이즈 닭껍데기 열풍에 합류'",
#  '\'\\ATV 몰고 빈탄섬 질주해보세요\\"\'"',
#  "'④ '거기서 뭐 하세요?''",
#  "'② '받아라 강스파이크!''",
#  "''데뷔 3년' 5월 히트곡 뚜두뚜두 뮤직비디오가 K팝...'",
#  "'인도네시아어, 2019년 07월 20일 오늘의 외국어 한마디는?'",
#  "'해외 매체들, 방탄소년단 뷔, 배려와 가족 사랑의 아이콘 극찬!'",
#  "''뚜두뚜두' 이들은 지난해 11월 서울을 시작으로...'",
#  "'유권, 손님맞이 나서자 팬미팅 방불'",
#  "'알맹이는 가라… 닭껍질부터 귤껍질까지 '껍데기' 전성시대'",
#  "''뚜두뚜두' 블랙핑크 월드투어는 전 세계 굵직한...'",
#  "''팔아야 귀국' 멤버들 인도네시아 현지 홈쇼핑 쇼 호스트로 변신'",
#  '\'인니 코모도섬 내년부터 최소 1년 폐쇄…\\멸종 막을 것\\"\'"',
#  "''진범' 제23회 부천국제판타스틱영화제 국제경쟁 부문 부천 ...'",
#  "'인니 방영 만화 40% 한국산…오승현 애니 감독 '깃발 꽂아''",
#  "'정승환, “USㅤㅤㅤㅤㅤㅤ-US(어스) OFFICIAL LOGO-1. 그래픽 모티브...”'",
#  "'‘팔아야 귀국 in 인도네시아’, 현지 홈쇼핑에서 홍보 도전하다'",
#  "'항공사 기내 '손글씨 메뉴' SNS에 올리면 명예훼손될까? '",
#  "'환경부 주간 계획(7월22~26일)'",
#  "'‘US-US(어스) OFFICIAL LOGO-1. 그래픽 모티브...’'",
#  "'① '몸매 말고 경기에 집중을!''",
#  '\'인도네시아 \\한국에 KF-X 분담금 낼 예산 없어\\"\'"',
#  "'印尼, 우리나라에 차세대 전투기 사업 분담금 축소 요청'",
#  '\'인도네시아 \\한국에 KF-X 분담금 낼 예산 없어… 축소 원해\\"\'"',
#  "''뚜두뚜두' 블랙핑크는 지난 4월 12일 현지시간...'",
#  "''뚜두뚜두' 최근 발매한 앨범 타이틀곡 킬...'",
#  "'동방신기, 22곡으로 꽉 채운 홍콩 앙코르 콘서트'",
#  "'동방신기, 홍콩 앙코르 콘서트 성료 “여러분과 함께해서 행복한 시간 만들 수...'",
#  "'여자친구, 말레이시아→싱가포르 접수 ‘亞 정복 청신호’'",
#  "'동방신기, 홍콩 앙코르 콘서트 성황리에 “열정적 응원에 행복한 시간”'",
#  "'여자친구, 亞투어 싱가포르 공연 성료..세계평화 유닛 무대까지 '혜자롭다''",
#  "'여자친구, 아시아 투어 'GO GO GFRIEND!' 싱가포르 공연 성료... 유닛 무대로...'",
#  "'동방신기, 홍콩 앙코르 콘서트 성료…퍼포먼스 최강 듀오의 명품 공연 선사'",
#  "'인도네시아 10대 스타 자라, 방탄소년단 지민을 향한 팬심!'",
#  '\'인도네시아 10대 스타 자라(Adhisty Zara), \\지민은 내 남편이야~!\\"\'"',
#  "'동방신기, 홍콩 앙코르 콘서트 성료...퍼포먼스 최강듀오 폭발'",
#  "'동방신기, 홍콩 앙코르 콘서트 성료…현지 관객 완벽 매료'",
#  "'여자친구, 싱가포르 공연 ‘GO GO GFRIEND!’ 성료…아시아투어 순항 中'",
#  "'여자친구, 싱가포르 공연 성료.. 아시아 투어 순항 中'",
#  "'여자친구, 싱가포르 공연서 데뷔 전 그룹 후보 '허그허그''세계평화' 결성'",
#  "'소녀시대 수영 ‘수줍은 소녀의 하트’'",
#  "' 수영 '상큼한 하트''",
#  "' 수영 '꾸민듯 안꾸민듯~''",
#  "' 수영 '멀리서도 한 눈에 들어오는 미모''",
#  "'94살 '마하티르의 위대한 선택', 말레이시아 18살에 국회의원 출마 가능'",
#  "'수영 간판 김서영, 개인혼영 200m 준결승 가볍게 진출'",
#  "'여자친구, 서울→싱가포르까지 투어 순항중…亞 정복 청신호'",
#  "'‘최강 듀오’ 동방신기, 홍콩 앵콜콘 퍼펙트한 마무리'",
#  "'국토부와 진흥원, 철도부품 국산화와 동반성장 나서'",
#  "'여자친구, 아시아 투어 싱가포르 공연 성료...'열정＋열기' 210분'",
#  "' 수영 '눈부신 미모''",
#  "'수영, '출국장으로 향하는 발걸음''",
#  "' 물오른 미모 수영 '바람은 거들뿐''",
#  "'소녀시대 수영 ‘청순함의 대명사’'",
#  "'김판석 교수, 인도네시아 신임 공무원 특강 나선다'",
#  "' 수영 '화보 촬영 떠나요~''",
#  "'소녀시대 수영 ‘날개 달린 천사 하트’'",
#  "' 수영 '걷기만 해도 화보''",
#  "'수영, '멀리서도 돋보이는 매력''",
#  "' 수영 '정경호는 이 하트 매일 받나~~''",
#  "' 수영 '안녕~''",
#  "'수영, '출국길 머리정리''",
#  "' 수영 '시원한 화이트 팬츠로 멋내고''",
#  "' 수영 '분위기 여신의 등장''",
#  "' 수영 '이렇게 예쁘면 반칙~''",
#  "' 수영 '연예인 포스~''",
#  "'대전도시공사 펜싱팀 손영기 세계선수권 銅메달'",
#  "'수영, '매력 넘치는 미모''",
#  "' 발리로 출국하는 수영 '화보는 지금부터''",
#  "'수영, '바람에 찰랑이는 머릿결''",
#  "'소녀시대 수영 ‘길 건너에서 햇살 미소’'",
#  "' 수영 '무결점 피부 미인''",
#  "' 수영 '1초면 심쿵~''",
#  "'수영, '화보 같은 출국길''",
#  "'소녀시대 수영 ‘멀리서부터 풍기는 여신美’'",
#  "' 수영 '바람불어 더욱 빛나는 미모''",
#  "' 수영 '하트 날리고 싶은 미모''",
#  "'수영, '발리 다녀올게요~''",
#  "' 발리 출국하는 수영 '시크한 인사''",
#  "'수영, '심플한 공항 패션''",
#  "'소녀시대 수영 ‘머리만 넘겼을 뿐’'",
#  "' 수영 '예쁨 가득한 하트''",
#  "'소녀시대 수영 ‘분위기가 다했네’'",
#  "' 수영 '화보는 공항부터 찍는다''",
#  "'동방신기 '홍콩 앙코르 콘서트'…현지 관객 열광'",
#  "' 수영 '완벽한 비율 뽐내며~''",
#  "'소녀시대 수영 ‘팬들 보니 미소가 저절로’'",
#  "' 수영 '어마어마한 롱다리 뽐내며~''",
#  "' 수영 '사랑해~''",
#  "'소녀시대 수영 ‘옅은 미소로’'",
#  "'2019년 ‘하이원 드림 원정대’ 발대식'",
#  "'소녀시대 수영 ‘운동화 신고도 완벽한 9등신 비율’'",
#  "'소녀시대 수영 ‘흐린 날 촉촉하게’'",
#  "'수영, '사랑스럽게~''",
#  "'소녀시대 수영 ‘무엇 하나 빠지지 않는 완벽함’'",
#  "'수영, '손하트도 시크하게''",
#  "' 수영 '자체발광 미모''",
#  "'수영, '예쁘게 찍고 올게요~''",
#  "'수영, '손하트는 쑥스러워요''",
#  "' - 15:00'",
#  "' 수영 '물오른 여성미''",
#  "'국토부-진흥원 맞손, 철도부품 국산화 및 동반성장 추구'",
#  "'소녀시대 수영 ‘이마도 예쁜 사람’'",
#  "'소녀시대 수영 ‘미소를 활~짝’'",
#  "'소녀시대 수영 ‘셔터만 누를 때마다 화보 컷’'",
#  "'소녀시대 수영 ‘선글라스 위로 눈빛이 살짝’'",
#  "'소녀시대 수영 ‘다리길이가 어마어마’'",
#  "' 수영 '심쿵 하트로 매력 발산''",
#  "'대전도시공사 펜싱팀 손영기 세계선수권 동메달 획득'",
#  "'‘데뷔 3년’ 블랙핑크는 지난 4월 12일 현지...'",
#  "'‘톱클래스 그룹’ 동방신기, 홍콩 앙코르 콘서트 성료..다채로운 무대 선사'",
#  '\'동방신기, 홍콩 앙코르 콘서트 성황 \\열정적 응원 감사\\"\'"',
#  "'여자친구, 아시아 투어 싱가포르 공연 성료!! 아시아 투어 순항 中'",
#  "'동방신기, 홍콩 앙코르 콘서트 성료'",
#  "'여자친구, 亞투어 싱가포르 공연 성료..열기 가득'",
#  "'소녀시대 수영 ‘찰랑이는 우아함’'",
#  "'소녀시대 수영 ‘도도한 워킹’'",
#  "'소녀시대 수영 ‘발리로 떠나요~’'",
#  "'2020년 어라운드 삼척, 우리나라 최초 UCI 그란폰도 월드시리즈(GFWS) 등록 쾌...'",
#  "'‘데뷔 3년’ 유럽 투어와 오세아니아 투어 역시...'",
#  "'여자친구, 서울→말레이시아→싱가포르 '글로벌 친구 우뚝''",
#  "'플라즈맵, 동남아 시장 진출..현지사무소 설립해 교두보 확보'",
#  "'인도네시아선 한국이 '김 종주국'…일본의 10배 수출'",
#  "''K팝 걸그룹 최초' 블랙핑크 월드투어는 전 세계 굵직한...'",
#  "' 관심과 부담 사이 놓인 김서영, 홀로 짊어진 한국 수...'",
#  "'대전도시공사 펜싱 손영기 세계선수권 동메달'",
#  "'김판석 前인사혁신처장, 印尼 신임공무원 대상 특강'",
#  '\'\\그랩·고젝의 성공 보고자란 C세대 창업정신 역대 최강\\"\'"',
#  "'대전도시공사 손영기 세계 3위'",
#  "'윤아, 수영복 자태 뽐내며 청순미 발산'",
#  "'대점도시공사 펜싱팀 손영기, 세계선수권 銅메달'",
#  "'김판석 전 인사혁신처장 印尼서 특강'",
#  "'강원랜드, 2019 하이원 중·고등학생 드림 원정대 발대식 개최'",
#  "'강원랜드, ‘2019 하이원 드림 원정대’ 발대식'",
#  "'김판석 전 인사혁신처장, 印尼 공무원 6000명에 특강'",
#  "'KARA, ‘2019 아시아 오토 짐카나’ 2라운드 인제서 진행'",
#  "'‘화훼종자’ 명확한 기준도 없는데 원산지 쓰라니…'",
#  "'손영기, 펜싱 세계선수권대회 남자 플뢰레 개인전 동메달'",
#  "'김승진·이우진, 실업 근대5종 金'",
#  '\'\'女개인혼영 200m 결선\' 김서영, \\다른 사람 아닌 나를 위해 후회없이 도전\\" ...\'"',
#  "' 광주 찾은 박태환 “김서영 힘든 부분 공감… 잘 이겨...'",
#  "'“냥질라?” 서울 집어삼킨다는 '거대 고양이' 정체'",
#  "'7월 22일 동정'",
#  "'‘뚜두뚜두’ 공개 329일만의 기록으로 싸이 외에...'",
#  '\'동방신기, 홍콩 앙코르 콘서트 성료…\\열정적 응원 감사해\\"\'"',
#  "'인도네시아 “한국에 KF-X 분담금 낼 예산 없다”'",
#  "'종근당 '글로벌 色' 짙어진다… 혁신의 원년'",
#  "'‘구로다’의 망언을 규탄한다!'",
#  "' 아시아 권위주의 새 도구로 떠오른 '인터넷 차단''",
#  "'김판석 교수, 인니 대통령과 현지 특강'",
#  "'‘800조원 블루골드’ 세계 물시장을 잡아라'",
#  "'‘톱클래스’ 동방신기, 홍콩 앙코르 콘서트 성황 마무리'",
#  "'인천공항 이소희-신승찬, BWF 인도네시아오픈 값진 동메달'",
#  "'전북 군산 어청도 해역서 규모 2.0 지진 발생…7월 들어 6번째 지진 발생으로...'",
#  "'트랜스젠더 이슬람 학교 교장, 인권상 수상'",
#  "'친환경 여행문화, “약간의 불편으로 큰 보람 체험”'",
#  "'경주 천북농협 로컬푸드직매장, 개장 2년 만에 매출 2배로 급증'",
#  "'‘김스치면인연’ 방탄소년단 뷔, ‘다정보스’라 불린 이유'",
#  "'대한자동차경주협회, 인제스피디움에서 '2019 아시아 오토 짐카나 대회' 2라운...'",
#  '\'\\농식품 아이디어로 서울먹거리창업센터에서 꿈을 이루세요\\"\'"',
#  "' '사연있어 보이네'…수영, 한껏 분위기 잡은 출국길'",
#  "'인도네시아 언론, \\손흥민 인기",
#  "'카카오페이지, 카카오 자금수혈로 실탄 확보…글로벌 공략 ‘박차’'",
#  "'인도네시아어, 2019년 07월 22일 오늘의 외국어 한마디는?'",
#  "'보치아 간판 강원전사 정호원 아시아_오세아니아 선수권 銅'",
#  "'종근당 할랄 인증 받고 항암제 생산'",
#  "'탄환 10개만 제거하고 64개는 몸에 박힌 채 생활 한 '호프'...기력 회복 중[글...'",
#  '\'女 스태프 성폭행 혐의 강지환...\\기억이 없다\\"\'"',
#  "'환경부, 통합 물관리 따른 지하수 재조명'",
#  "' 미중, 오사카 담판 이후 첫 전화접촉'",
#  "' 32. suns...'",
#  "'종근당,\xa0인도네시아 항암제 공장 준공…글로벌 진출 가속화'",
#  "'김혜수 , '빈털터리 될 때야 끝나' , 품격 잃지않고 묵묵히'",
#  "'은지원, 전과 후가 같은 이 남자'",
#  "'종근당, 인도네시아 항암제 공장 준공…글로벌 진출 가속화'",
#  "'인도네시아, 호주에 쓰레기 200t 반송'",
#  "'유통업계, 초복 맞아 보양식 할인 경쟁 돌입'",
#  "'종근당 할랄인증 받고… 인도네시아 항암제 공장 준공'",
#  "'종근당 인도네시아 항암제 공장 준공…글로벌 시장 첫 진출'",
#  "'종근당, 인도네시아 항암제 공장 준공'",
#  "'종근당, 印尼에 항암제 공장… 글로벌 진출 첫발'",
#  "'은지원, '비교 인터뷰' 공개..20년 전 질문에 다시 답했다'",
#  "'“요즘 닭껍질이 인기라길래...” 세븐일레븐이 준비한 놀라운 신상'",
#  "'도내 기업 4곳 `해외조달시장 진출 유망기업' 선정'",
#  "' 집에서 즐기는 동남아시아 정통의 맛'",
#  "'인도네시아어, 2019년 07월 11일 오늘의 외국어 한마디는?'",
#  "'김혜수 , 의절했지만 맺고 끊기를 , 꽃길만 걸어라 격려가'",
#  "'인도네시아 항암제 공장 준공, 종근당 350억 투자해 유럽 확대 기대'",
#  "'김혜수 , '의절'했다지만 맺고 끊기가 , 꽃길만 걸어라 성원도'",
#  "'무등도요 권승찬·조장현 작가 ‘인니’ 간다'",
#  "'종근당, 인도네시아에 항암제 공장 준공'",
#  "'보잉 2분기 인도수 급감'",
#  "'한국제약바이오협회, 인도네시아제약협회와 MOU'",
#  "'종근당, 인도네시아 항암제 공장 준공... 글로벌 진출 가속화 될 것'",
#  "' 종근당, 인도네시아 항암제 공장 준공 소식에 오름세'",
#  "'종근당, 인도네시아 항암제 공장 준공…이장한 회장 “글로벌시장 공략”'",
#  "'연간 160만 바이알 생산 가능..종근당, 인도네시아 항암제 공장 준공'",
#  "'젊은의사 역량 강화 사업은 미리 준비하는 의료계의 미래'",
#  "' 유네스코 세계유산 한국은 14건…가장 많은 나라는?'",
#  "' 7월11일…일본 간 이재용 부회장·한국 부자순위·100일 맞은 ...'",
#  "' 집에서 즐기는 동남아시아 정통의 맛'",
#  "'부산에서 인도네시아 직항 뜰까'",
#  "'한패스, 호주 달러 등 5개국 통화 환전 추가'",
#  "'핀란드 이어 인도네시아도 부산발 직항 뜰까'",
#  "' 카이스트, 인도네시아 포함 동남아 국가 신생 벤처기업 육성...'",
#  "'인도네시아 국내선 저비용항공 '특정 요일·시간 반값''",
#  "'인도네시아와의 항공회담 8월 13, 14일 서울에서 열린다.'",
#  "'한국제약바이오협회, 인도네시아제약협회와 MOU 체결'",
#  "'김혜수 , 의절했다지만 맺고 끊기가 , 꽃길만 걸어라 성원도 , 책임없다 판결...'",
#  "'메트로신문 7월 11일자 한줄뉴스'",
#  "'부산에서 인도네시아 직항 뜰까'",
#  '\'\\초복에 몸보신하세요\\"… 익숙한 삼계탕 대신 별미·간편식 대세\'"',
#  "'종근당, 인도네시아 GMP‧할랄 인증 획득에 이어 항암제 공장 준공…해외 진출...'",
#  "'성동구, '최고 경제리더 양성' 과정 수료식 개최'",
#  "'인도네시아, 반입 쓰레기 검사하는 세관원'",
#  "'한패스, 호주 등 6개 통화 환전 확대'",
#  '\'인니 해수부 장관, 저커버그에 \\패들보드 경기하자\\"\'"',
#  "'한패스, 루피·링깃까지 환전 통화 확대'",
#  "'인도네시아, 호주서 수출 된 쓰레기 210톤 반송'",
#  "''쓰레기는 이제 그만!' 인도네시아 수라바야'",
#  "'해외매체들, 방탄소년단 정국 헤어스타일 '세계 8대 불가사의'로 칭한 이유'",
#  '\'\\초복에 몸보신하세요\\"… 익숙한 삼계탕 대신 별미·간편식 대세\'"',
#  "'구글플레이, 앱·게임 개발사 대상 오디션 프로그램 ‘100인의 선택, 턴업 20...'",
#  "'동네 개구쟁이가 아니라 한국 국가대표입니다'",
#  "'진정한 힐링 휴가를 원하세요? ②'",
#  "'방탄소년단 정국, 북미매체 선정… 당신을 절대적으로 사로잡을 아름다운 눈을...'",
#  "'도시에서 농사를 지읍시다'",
#  '\'종근당, 인도네시아 항암제 공장 준공…\\글로벌 진출 원년\\"\'"',
#  "'대웅제약, 글로벌 R&D네트워크로 현지지배력 강화 ‘장기전’ 돌입'",
#  "'종근당, 인도네시아에 항암제 공장 준공... 현지화로 시장 공략'",
#  "'한국-인도네시아 하늘길 넓어지나? '운수권 증대' 여부에 촉각'",
#  "'英 언론 “BTS 지민, 왕실로맨스와 찰떡…인어공주 ‘에릭왕자’에 최적”'",
#  "'구글플레이, 앱·게임 개발사 대상 오디션 프로그램 ‘100인의 선택, 턴업 20...'",
#  "'한국제약바이오협회, 인니제약협회와 MOU'",
#  "'해외언론 “BTS 지민, 인어공주 ‘에릭왕자’역에 최적임” 찬사'",
#  "'방탄소년단 지민→ 영화 '인어공주' 에릭왕자 지목?'",
#  "'BTS 지민 '인어공주' 캐스팅 청원 열풍…美·英 외신들 긍정 '",
#  "'국내외 지하수 전문가 한곳에 … 환경부 '그라운드워터 코리아''",
#  "'종근당, 印尼에 항암제공장 준공… 글로벌진출 박차'",
#  "'구글플레이, 앱/게임 개발자 대상 오디션 프로그램 '턴업 2019' 방영'",
#  "'한국제약바이오협회, 인니제약협회와 MOU'",
#  "'대웅제약, 글로벌 무대서 '나보타' 우수성 알려…'IMCAS Asia 2019' 참가'",
#  "''불탑의 도시' 바간 세계유산 등재...소수서원 등 '한국의 서원'도'",
#  "'인도네시아 K-Food B2B2C 프로모션 참가 기업 모집'",
#  "'전주삼성로하스의원 고형석 원장, 미용성형학회 IMCAS(임카스) 아시아 학회서...'",
#  "'구글플레이, 앱·게임 개발사 대상 오디션 프로그램 '100인의 선택, 턴업 201...'",
#  "'인도네시아 K-푸드 프로모션 참가기업 모집'",
#  '\'한패스 \\호주 달러 외 5개국 통화 추가…16개국 통화 환전 가능\\"\'"',
#  "' 유로무역, 영국 프리미엄 르토이반 원목 교구 선봬'",
#  "'대웅제약, 글로벌 무대서 '나보타' 우수성 알려…'IMCAS Asia 2019' 참가'",
#  "'인도네시아 빈탄섬 오아시스 '더 레지던스''",
#  "'앱·게임 개발사 오디션 프로그램 '100인의 선택, 턴업 2019' 14일 방영'",
#  '\'유럽 라이언에어 \\11월까지는 보잉 맥스 운항 재개 해야\\"...매출 타격 우려\'"',
#  "'강원장애인체육회, 직장운동경기부 보치아팀 창단'",
#  "'“역시 만찢남” 전세계가 인정한 인어공주 에릭왕자와 '지민' 싱크로율'",
#  "'제약바이오협회, 인도네시아제약협회와 사업 협력 MOU'",
#  "'한국-인도네시아 항공회담 8월 서울서 열려'",
#  "'한패스, 호주 달러 등 6개국 통화 환전 서비스 추가'",
#  "'IMCAS Asia 2019 참가한 '은성글로벌' 신제품 선보여 호평 받아'",
#  "'껍질이 더 좋아...치킨집 매출 10배 늘려 준 신제품은'",
#  "'인도네시아 빈탄섬 오아시스 '더 레지던스''",
#  "'도심에서 펼치는 비치발리볼 열전'",
#  "'대구 도심에서 비치발리볼 대회 개최'",
#  "'빈탄섬 망망대해 보며 여름휴가 어떠세요'",
#  "'클럽메드 빈탄 아일랜드서 체험하는 공중그네'",
#  "'더 레지던스 빈탄 시그니처 플로팅 조식'",
#  "'도심에서 펼치는 비치발리볼 열전'",
#  "'환호하는 이스라엘'",
#  "'공격하는 인도네시아'",
#  "''공격''",
#  "'공격 성공후 기뻐하는 선수들'",
#  "''공격해봐''",
#  "'2019 대구비치발리볼 월드투어 수성못서 개최'",
#  "''강스파이크''",
#  "'해외 언론 “BTS 지민, 인어공주 ‘에릭왕자’역에 최적” 호평'",
#  "'국내 대표 개발사 뽑는 대국민 오디션 프로그램 '턴업 2019', 14일 전파탄다'",
#  "'환호하는 이스라엘'",
#  "'인도네시아 서브를 보여주마'",
#  "'높이 올려'",
#  "'2019 대구비치발리볼 월드투어 개막'",
#  "'2019 국제배구연맹 비치발리볼 월드투어 대구서 개막'",
#  "'도심서 열린 2019 국제배구연맹 대구비치발리볼 월드투어'",
#  "'대구 도심서 열린 비치발리볼 월드투어'",
#  "''작전 2번''",
#  "''강서브''",
#  "'수비하는 인도네시아 선수'",
#  "'2019 대구비치발리볼 월드투어'",
#  "'인도네시아 서브를 보여주마'",
#  "'해변 없는 대구에서 '국제배구연맹 대구비치발리볼 월드투어''",
#  "'집중'",
#  "'때려'",
#  "'끝까지 받아'",
#  "'파워 리시브'",
#  "'막아봐'",
#  "'공격 준비'",
#  "'득점이야'",
#  "'국제배구연맹 대구비치발리볼 월드투어 개막'",
#  "'공격준비'",
#  "'해변 없는 대구에서 '국제배구연맹 대구비치발리볼 월드투어''",
#  "'득점 좋아'",
#  "'힘껏 때려'",
#  "'높이가 다른 서브'",
#  "'힘이 넘치는 공격'",
#  "' 보는 즐거움이 '쏠쏠' 도심 비치발리볼 대회'",
#  "'다시 공격해'",
#  "'우아한 서브'",
#  "'호흡 척척'",
#  "'모래 위의 미녀'",
#  "'가볍게 넘겨'",
#  "'득점 좋아'",
#  "' ‘G20 동영상’ 팩트체크 이후 논란을 팩트체크하다'",
#  "'합천군, 냉동 딸기 인도네시아 첫 수출'",
#  "'성 김, 주인도네시아 미국 대사에 지명'",
#  "'킹콩부대찌개, 인도네시아 프랜차이즈 박람회 성료 및 마스터프랜차이즈 MOU ...'",
#  '\'박원순, 세계도시 정상회의 기조발표…\\서울은 사람의 도시\\"\'"',
#  '\' 신남방서 북미·아프리카까지..\\상대국과 같...\'"',
#  "'한국-인도네시아 항공회담, 내달 서울서 열려'",
#  "' 모래 위의 미녀들 (NC화보)'",
#  "' 美 동영상 공유 핀터레스트, 싱가포르에 거점 설치'",
#  "'동아·대웅제약 이어 종근당도 인도네시아 진출'",
#  "' ‘G20 동영상’ 팩트체크 이후 논란을 팩트체크하다'",
#  "'필리핀 가족주의·인니 힌두불교…우리가 잘 몰랐던 동남아'",
#  "'대구 도심서 펼치는 비치발리볼 열전'",
#  "'천송어린이합창단, 이탈리아 피렌체 '국제합창축제' 참가'",
#  "' 보잉 2분기 수주 13대 전년의 20분의 1 토막…잇단 추락사고...'",
#  "'자유투어 동남아패키지 ˝마사지 받으며 휴가 즐길 수 있어˝'",
#  "' 한달새 세 번이나 몸 떤 메르켈 총리…‘건강이상설’'",
#  "' 넥슨, '카스온라인' 인도네시아 서비스 8월1일 종료'",
#  "'필리핀 가족주의·인니 힌두불교…우리가 잘 몰랐던 동남아'",
#  "'무협, ‘할랄인증’ 통한 무슬림 공략 세미나 개최'",
#  "'구글, 국내 앱·게임 개발사 오디션 시작'",
#  "'무협, 할랄 인증으로 20억 무슬림 공략 지원'",
#  "'무협, '할랄인증으로 20억 무슬림 공략하기' 세미나 개최'",
#  "'미래차 투자 집중위해 몸집 줄여가는 외국 완성차 업체…현대차는 '역주행''",
#  "'강경화 장관, 아프리카 외교의 중심 아프리카연합(AU)과의 협력 강화'",
#  "'“스마트시티, 서울”… 혁신정책 세계에 알렸다'",
#  "'성 김, 인도네시아주재 美대사로'",
#  "'무협, ‘할랄인증’ 통한 무슬림 공략 세미나 개최'",
#  "'‘추락 사고’ 보잉 737 운항 프로그램 매니저 사임'",
#  '\'창립 78년 만에 매출 1조 돌파 앞둔 종근당…\\올핸 글로벌 진출 원년\\"\'"',
#  '\'\\애완동물로 키우려고\\" 발리서 아기 오랑우탄 약 먹인 뒤 밀반출 시도한 러시...\'"',
#  '\'\\애완동물로 키우려고\\" 발리서 아기 오랑우탄 약 먹인 뒤 밀반출 시도한 러시...\'"',
#  "'텐센트, '체스러쉬' 글로벌 스타 챌린지 개최'",
#  "'텐센트, '체스러쉬' 글로벌 스타 챌린지 개최'",
#  '\'\'346명 사망\' 737맥스 총괄 관리자 은퇴…\\사고 때문 아냐\\"\'"',
#  '\'\'346명 사망\' 737맥스 총괄 관리자 은퇴…\\사고 때문 아냐\\"\'"',
#  "'KLCSM, '안전운항 컨퍼런스' 개최'",
#  "'中,믈라카해협에 긴급경보 발령…중국 해군 파병 구실?'",
#  "'앱·게임 개발사 대상 오디션 프로그램 나온다'",
#  "''팔아야귀국' 유권, 자카르타 시장 한복판서 눈물 흘린 사연은?'",
#  "'맞춤 전략으로 빠른 시장 침투… 제약업계, 글로벌 '현지화' 확산'",
#  "'즉석밥 속 일본산 미강추출물 논란, ‘미강추출물’이 뭐야?'",
#  "'‘팔아야 귀국’ 블락비 유권, 인도네시아 시장 한복판서 눈물 흘린 사연'",
#  '\'길산·청산 한중합작 GTS 부산 공장설립 \\STS 범람 vs 기술혁신\\"\'"',
#  "'성동구,'성동 글로벌 교환근무'운영'",
#  "'소녀시대 수영의 공항패션 속 선글라스, 래쉬'",
#  "'한국관광공사, 1박2일간 '친환경 여행단' 행사'",
#  "'줄서서 먹는다는 닭껍질 튀김의 비밀'",
#  "'텐센트 '체스러쉬', 글로벌 e스포츠 대회 '글로벌 스타 챌린지' 개최'",
#  "''팔아야 귀국' 유권, 지옥맛 예능신고식‥시장 한복판서 눈물 흘린 사연'",
#  "'앱 개발사 오디션 프로그램 '100인의 선택, 턴업 2019' 14일 첫방송'",
#  "' 양의식 회장 “모델은 패션ㆍ뷰티 산업 발전의 척도”'",
#  "''팔아야 귀국' 유권, 인도네시아 매운 고추 맛본 뒤 '경악' '",
#  "'‘블락비’ 유권, 자카르타 시장 한복판에서 눈물 흘린 사연은?'",
#  "'한국체외진단의료기기협회, 제1회 정기총회 개최'",
#  "'줄서서 먹는다는 닭껍질 튀김의 비밀'",
#  "'은지원, ‘불나방’ 라이브 영상 공개! 27~28일 솔로 단독 콘서트!'",
#  "'은지원, '불나방' 라이브 영상 공개..대체 불가 카리스마'",
#  '\'\\지하수이용부담금 체계 개선 시급\\"\'"',
#  "'은지원, '불나방' 라이브 영상 공개…27·28일 솔로 단독 콘서트 개최'",
#  "'합천군, 냉동 딸기 인도네시아 첫 수출 선적식'",
#  "'은지원, '불나방' 라이브 영상 공개..27-28일 솔로 단독 콘서트 기대↑'",
#  "'바다 아닌 곳에서도 '비치발리볼', 대구 수성못서 대회 개최'",
#  "'은지원, 신곡 ‘불나방’ 라이브 영상 공개 ‘대체불가 카리스마’'",
#  "'은지원, '불나방' 라이브 영상 공개…대체 불가 카리스마'",
#  "'부테이코: 인도네시아 여성 가수가 잘 때 입에 테이프를 붙이는 이유'",
#  "'은지원, ‘불나방’ 라이브 영상 공개! 27~28일 솔로 단독 콘서트!'",
#  "'진에어 삼중고에 시름, '일본노선 부진' '중국노선 배제' '국토부 제재''",
#  "'정 많은 한국인이 해외에서 가장 많이 당하는 사기는?'",
#  "'엠알피파트너스, 바이오인더스트리 기업 '해나눔'과 MOU체결…'올바른감량' 브...'",
#  "'‘팔아야 귀국’ 멤버들 집단 패닉?? 거리에서 사라진 인도네시아 사람들'",
#  "'제약사 플랜트, 인니 현지 거점 구축 이유는'",
#  "'진에어 삼중고에 시름, '일본노선 부진' '중국노선 배제' '국토부 제재''",
#  "'은지원, 신곡 ‘불나방’ 라이브 영상 공개 ‘웃음기 0%’'",
#  "'은지원, ‘불나방’ 라이브 영상 공개…대체 불가 카리스마'",
#  "'싱가포르·중국 이어 인니까지…항공업계 하늘길 개척 '박차''",
#  "'은지원, 신곡 ‘불나방’ 라이브 영상 공개 ‘웃음기 0%’'",
#  "'<팔아야 귀국> 멤버들 집단 패닉?? 거리에서 사라진 인도네시아 사람들?!'",
#  "' 손정의가 “AI에 집중하라” 강조하는 이유'",
#  "'발리 호텔 물리아의 이상과 추구, '아페리체나, 미슐랭 디너' 선봬'",
#  "'인니, '아동 성폭행' 징역 11년 선고된 캐나다인 교사 사면'",
#  "'매일 잠든 2세 아들 입을 테이프로 막는 여성, 이유는?'",
#  "'선박관리전문회사 KLCSM, 부산에서 선박 안전운항 세미나 개최'",
#  "' - 월드미션 브리...'",
#  "'로이문화예술실용 전문학교 호텔식음료 칵테일과정, 믹솔로지스트 맞춤 교육'",
#  "'‘팔아야 귀국’ 멤버들 집단 패닉된 사연은?'",
#  "'최저임금 8590원... '알바'해서 해외여행 떠나볼까?'",
#  "' 손정의가 “AI에 집중하라” 강조하는 이유'",
#  "'“BTS 지민, ‘인어공주’ 에릭 왕자와 닮아” 팬들 캐스팅 요청'",
#  "'“BTS 지민, ‘인어공주’ 에릭 왕자와 닮아” 팬들 캐스팅 요청'",
#  "' 블락비 유권, 자카르타 시장 한복판에서 지옥맛 예능신고식'",
#  "' 블락비 유권, 자카르타 시장 한복판에서 지옥맛 예능신고식'",
#  "' '라마단' 기간에 팝업스토어 오픈해 멤버들 집단 패닉'",
#  "' '라마단' 기간에 팝업스토어 오픈해 멤버들 집단 패닉'",
#  "'‘2000원 짜리 오페라’가 부산에 등장했다'",
#  "'2019년 미스그랜드코리아 진(眞)의 영예 박세림'",
#  "'2019년 미스그랜드코리아 진(眞)의 영예 박세림'",
#  "'몽골, 인도네시아 등 3개국 교류도시직원 성동구서 근무'",
#  "'박형구 “중부발전은 해외사업에서 새 성장동력 찾겠다”'",
#  "'박형구 “중부발전은 해외사업에서 새 성장동력 찾겠다”'",
#  "' 전세계 K-콘텐츠 열풍…그 중심 CJ ENM'",
#  "'천연가스파이프라인 활용 등 제안'",
#  "'천연가스파이프라인 활용 등 제안'",
#  "'인니 선정 '차세대 유니콘' 44개에 韓 스타트업 포함'",
#  "'‘팔아야 귀국’ 신봉선, 장동민에 “집중하는 모습 잘 생겼다”'",
#  "''팔아야 귀국' 블락비 유권 달달한 통화...8년 사귄 여친 전선혜와 '꽁냥꽁냥...'",
#  "'한국 농구, 대만 B팀 꺾고 윌리엄존스컵 2연승'",
#  "''이대성-라건아 38득점' 한국, 존스컵 2연승'",
#  "'무협, 인니서 ‘K-스타트업 글로벌 멘토링 프로그램’ 개최'",
#  "'무협, 자카르타서 'K-스타트업 멘토링 프로그램' 개최'",
#  "'무협, 인도네시아서 '2019 K-스타트업 글로벌 멘토링' 개최'",
#  "'무협, 인도네시아서 'K-스타트업 글로벌 멘토링' 진행'",
#  "'무협, 자카르타서 ‘K-스타트업 멘토링 프로그램’ 개최'",
#  "'화웨이, 2018년도 지속가능경영 보고서 발간'",
#  "'무협, 인니서 ‘K-스타트업 글로벌 멘토링 프로그램’ 개최'",
#  "'737맥스 후폭풍…보잉, 세계 1위 타이틀 놓치나'",
#  '\' \\부산은 특별한 도시\\" 힐튼 부산 노셀 총지배인\'"',
#  "'2억6000만명 ‘인니’ 시장 잡아라...프랜차이즈協, 인도네시아 시장 확산 위...'",
#  "' 한국프랜차이즈협회, 인도네시아 진출 촉진 위해 업무협약'",
#  "'한국프랜차이즈協, 인니 프랜차이즈 협회와 해외진출 협력 MOU'",
#  "'한국프랜차이즈協 'K-프랜차이즈' 인도네시아 진출 확산 위한 MOU 체결'",
#  "' 냉동 딸기 인도네시아 첫 수출 등'",
#  "'행안부, 인도·남아공 등 19개국 초청 스마트시티 워크숍 개최'",
#  "' 인도네시아 제약 시장이 주목받는 이유는?'",
#  "'무협, 인도네시아 '2019 K-스타트업 글로벌 멘토링 프로그램' 진행'",
#  "'2억6000만명 ‘인니’ 시장 잡아라...프랜차이즈協, 인도네시아 시장 확산 위...'",
#  "'한국 프랜차이즈, 세계로 위상 높인다···인도네시아 MOU 체결'",
#  '\'한국프랜차이즈協 \\인도네시아에 \'K-프렌차이즈\'확산시킬 것\\"\'"',
#  "''인도네시아 가는 길 화악~넓어질까' 여행업계 한국-인도네시아 항공회담에 촉...'",
#  "'무역협회, 자카르타서 `K-스타트업 멘토링` 개최'",
#  "'행안부, 인도·말레이시아 등 19개국 초청 ‘스마트시티 워크숍’ 개최'",
#  "' 화웨이, 미국 거래금지 조치에도 상반기 수익 증가'",
#  "'글로컬 시대 실리 외교 확장 꾀하는 전북도'",
#  '\'印尼 할마헤라 지역서 규모 7.3 지진...\\국내 영향없어\\"\'"',
#  "'인도네시아 몰루카제도 규모 7.3 지진으로 가옥 파손'",
#  "'인도네시아 진출 위해 업무협약'",
#  "' 무역협회, 자카르타서 K스타트업 바이어 상담회'",
#  "'유럽에 울려퍼진 제주어린이의 노랫소리'",
#  "'韓·인니 프랜차이즈協 업무협약'",
#  "'발리, 녹색부담금 도입 등 폐기물 관리 본격화'",
#  '\'프랜차이즈協 \\한국 기업 印진출 도와요\\"\'"',
#  "'합천\xa0‘첫눈에 반한 냉동 딸기’\xa0인도네시아 첫 수출'",
#  "'글로컬 시대 실리 외교 확장 꾀하는 전북도'",
#  "''라건아 21점' 김상식호, 이란 제압…존스컵 3연승'",
#  "'한국무역협회-과학기술정보통신부-문화체육관광부, 자카르타서 'K-스타트업 멘...'",
#  "'라건아 21점·이대성 18점… 한국, 이란 잡고 존스컵 3연승'",
#  '\'인니 말루쿠 제도에 규모 7.3 강진…\\쓰나미 경보 발령안돼\\"\'"',
#  "'인도네시아, 규모 7.3 강진 '석조 건축물 와르르''",
#  "' 호주 6.9 지진 7시간 만에 인도네시아 동북부서 규모 7.3 강...'",
#  "' '라건아-이대성 39P' 男대표팀, 이란에 4점차 진땀승'",
#  '\'프랜차이즈協 \\국내 기업 인도네시아 진출 돕는다\\"\'"',
#  "'인니 몰루카제도 규모 7.3지진 발생'",
#  "'인니 헬마헤라 섬에서 규모 7.1 강진'",
#  "''라건아 21점' 김상식호, 이란 제압…존스컵 3연승'",
#  "'지진 피해 길거리에 나온 주민들'",
#  "''팔아야 귀국' 우리나라처럼 인도네시아에서도 평소 매운 음식을...'",
#  "'인니 몰루카제도 규모 7.3 지진...쓰나미 경보 없어'",
#  "' 기자 꿈꾸던 ‘IQ140’ 청년, 방황 접고 주님과 동...'",
#  "'인도네시아 몰루카제도서 또 규모 7.3 지진… 쓰나미 경보 없어'",
#  "'울산조선해양플랜트사업협동조합 사업 설명회 개최'",
#  "'인도네시아 청소년 교류대표단, 울산외고 방문'",
#  "'울산조선해양협동조합 18일 사업설명회'",
#  "''라건아 21점' 한국농구, 이란 꺾고 존스컵 3연승'",
#  "'인니 몰루카제도 규모 7.3지진…쓰나미 경보 없어'",
#  "'지진 피해 길거리에 나온 주민들'",
#  "' 인도네시아 동부 규모 7.3 지진'",
#  '\'인도네시아서 규모 7.3 강진…\\쓰나미 가능성은 없어\\"\'"',
#  "'인도네시아어, 2019년 07월 15일 오늘의 외국어 한마디는?'",
#  "'합천군 냉동딸기 인도네시아 첫 수출'",
#  "'제약 글로벌 교두보, 왜 인도네시아인가?'",
#  "'보잉 737 맥스 기종 내년 초까지 지상에 발 묶여 있을 듯'",
#  "' 아나즈-이도정, '베스트드레서 아나즈상 수상~' (미스그랜드코리아)'",
#  "' 제2의 짜파구리 마트를 점령하다'",
#  "' 인천공항 2터미널 국제면허증 발급'",
#  "' 인도네시아 동부 규모 7.3 지진'",
#  "' 동인도회사의 기업가 정신과 창업'",
#  "'코스맥스, ‘K 뷰티’ 영향력 축소·매출 부진 지속…목표가↓-메리츠'",
#  "' 미쓰비시, 배상 협의 거부할 듯'",
#  "'한국피자헛, 대표이사 '공석' 사태 길어지나'",
#  "'합천 냉동 딸기 인도네시아 첫 수출'",
#  "''진범', 해외 5개국 선판매+대만 19일 개봉 확정...한국형 스릴러 通했다!'",
#  "'아침]2019 대구 비치발리볼 월드투어, 러시아 우승'",
#  '\'\\해외 5개국 선판매+대만 개봉 확정\\"…\'진범\' 한국형 스릴러 通했다\'"',
#  "'합천군청(종합), 합천군, 냉동 딸기 인도네시아 첫 수출'",
#  "'김상식호, 인도네시아 대파하고 존스컵 4연승'",
#  "'무슬림 잡아라… 할랄에 꽂힌 국내 제약사들'",
#  "'방탄소년단 정국, 美·中 연예매체 선정 '매력적인 턱선을 가진 남자 스타''",
#  "'블록체인 콘텐츠 플랫폼 '콘텐토스', 오는 18일 국내 밋업 개최'",
#  "' 아찔 절벽서 '풍덩'…레바논 다이빙 대회'",
#  "'겸손하고 예의바른 방탄소년단 뷔 ‘최고의 굿보이’'",
#  "'방탄소년단 정국, 美中 연예매체 선정 “매력적인 턱선을 가진 남자 스타!”'",
#  "' '진범' 해외 5개국 선판매 & 대만 개봉 확정'",
#  '\' 인도네시아 소녀들, 트럼프에 편지…\\왜 쓰레기 수출해요?\\"\'"',
#  "'인도네시아어, 2019년 07월 16일 오늘의 외국어 한마디는?'",
#  "'첫째도 둘째도 셋째도 AI라는데…'세계 100대 AI 스타트업'에 한국 '0''",
#  "'‘나 옛날 코( )라서’ 장동민은 한국에서 공수해온 철판을 활용해...'",
#  "'방탄소년단 정국, 美·中 연예매체 선정 '매력적인 턱선을 가진 남자 스타''",
#  "'서울아산, 해외 의료진 대상 내시경초음파검사 교육 실시'",
#  "'발리 지진, 규모 5.7…현지 여행객 반응 보니'",
#  "'인도네시아 발리섬 인근 해상서 규모 5.7 지진…쓰나미 발령 경보 無'",
#  "'인도네시아 발리 인근 해상 규모 5.7 지진 발생'",
#  "'인니 강간 피해자, 수술용 마스크로 얼굴 가린 사연'",
#  "'인도네시아 발리 인근 규모 5.7 지진…쓰나미 경보 없어'",
#  "'월드투어 떠나는 뉴이스트 황민현, 치명치명 매력 '",
#  ...]

# %%
#tep=title

# %%
## 정규표현식으로 '[]' 안에 있는거 제거.

# %%
#print(re.sub('[사진]', '',tep))

#리스트라서 하나씩
# tep1=[]
# for i in range(len(tep)) :
#     tep1.append(re.sub('[사진]','',tep[i]))

# print(tep1[:15])
# Out:
# ["'[]조여정,'우아한 플라워원피스 입고''", "'[프로필]국세청 과장급 전보자(7월 22일 자)'", "'[조이HD]춘영화제 참석한 봉준호 감독-한원 작가'", "'[]클라라,'시선 올킬 블루 롱드레스''", "'[]7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''", "'[]함소원,'우아한 입장''", "'[조이HD]엄태구, 지적인 남자야~'", "'[조이HD]기주, 매력적인 미모'", "'[조이HD]'기생충' 이정은, 엄마 미소~'", "'[조이HD]공명, 춘영화제 빛내는 미소~'", "'[조이HD]'춘영화제' 조여정, 칸이 반한 미소~'", "'[조이HD]'춘영화제' 문지인, 민트여신~'", "'[]공명,'훈남 매력''", "'무역위, 전기프라이팬 특허권 침해 불공정무역행위 조 개시'", "'[]베이비페이스 이성경,'화려한 변신''"]

# %% [markdown]
# ## 2) 한자변환 (Convert Chinese character)

# %%
tep=train['title']

# %%
#replace1=tep.replace(" ","")

# %%
replace1=tep.replace('日','일본')  # 안먹힘.

# %%
tep2=list(train['title'])

# %%
string = "sdf344asfasf天地方益3権sdfsdf".decode("utf-8")
for sub in cjk_substrings(string):
  string = string.replace(sub, "(" + sub + ")")
print string

## https://codeday.me/ko/qa/20190511/520930.html

# %%
replace1
# Out:
# 0                                   '조여정,'우아한 플라워원피스 입고''
# 1                                 '국세청 과장급 전보자(7월 22일 자)'
# 2                               '춘사영화제 참석한 봉준호 감독-한진원 작가'
# 3                                   '클라라,'시선 올킬 블루 롱드레스''
# 4                    '7개부문 노미네이트 기생충 봉준호 감독,'엄청난 환호 받으며''
# 5                                          '함소원,'우아한 입장''
# 6                                         '엄태구, 지적인 남자야~'
# 7                                          '진기주, 매력적인 미모'
# 8                                     ''기생충' 이정은, 엄마 미소~'
# 9                                     '공명, 춘사영화제 빛내는 미소~'
# 10                               ''춘사영화제' 조여정, 칸이 반한 미소~'
# 11                                   ''춘사영화제' 문지인, 민트여신~'
# 12                                           '공명,'훈남 매력''
# 13                     '무역위, 전기프라이팬 특허권 침해 불공정무역행위 조사 개시'
# 14                                  '베이비페이스 이성경,'화려한 변신''
# 15                                           '클라라,'섹시하게''
# 16                           '상체 노출 클라라,'이보다 더 아찔할 수 없어''
# 17                             '조여정, 춘사영화제 여우주연상에 빛나는 자태'
# 18                                    '함소원, 연하 남편을 향한 마음'
# 19                                 '춘사영화제 참석한 기생충 봉준호 감독'
# 20                                  '이정은,'영화 팬 여러분 사랑해요''
# 21                                         '문지인,'섹시 레드립''
# 22                                        '하지영,'어느덧 여배우''
# 23                                      '김강현,'춘사영화제 왔어요''
# 24                                          '공명,'달콤한 하트''
# 25                                      '전여빈, 우아한 블랙 드레스'
# 26                                  '전여빈, 춘사영화제가 주목하는 신예'
# 27                                            '공명,'젠틀하게''
# 28                                   '문지인, 10년차 베테랑 여배우~'
# 29                                        '전여빈,'아름다운 미소''
#                               ...
# 2843                                ' 日 스라라넷, 인니 교육대와 제휴'
# 2844                       '길 한복판서 고양이 산 채로 잡아먹은 남성 '충격''
# 2845                                  '옥천 복숭아 홍콩 판촉활동 전개'
# 2846                '올해 휴가 아직이라면? 내일투어와 함께 공짜 해외여행 떠나세요!'
# 2847                 '로드FC, 블루문펀드와 ‘손잡았다’…동남아시아 사업 확대 추진'
# 2848                         '네마프 2019, 덴마크 비디오아트 특별전 개최'
# 2849               '㈜에스엘에프앤비 킹콩부대찌개, 올해의 브랜드 대상 2년 연속 수상'
# 2850                    '남자가 고양이를 산 채로…‘엽기 영상’에 인도네시아 충격'
# 2851                              '동티모르, 아세안 11번째 회원국 될까'
# 2852             '부산대병원 컨소시엄, ‘WEB-PACS 시스템’ 카자흐스탄에 첫 수출'
# 2853        ''네마프 2019', 롯데시네마 홍대입구서 '덴마크 비디오아트 특별전' 개최!'
# 2854                 'ROAD FC, 블루문펀드와 손 잡았다…동남亞 사업 확대 추진'
# 2855                            '옥천군, 복숭아 홍콩 수출 확대 판촉 추진'
# 2856                           '해외바이어 초청 수출상담회, 흥행 성공 예감'
# 2857               ''광고 찍어도 되겠어'…여자친구 엄지, 똥머리+스포티룩 완벽 소화'
# 2858                                 ' 인도네시아 대통령 만나는 손정의'
# 2859    ''혈관+폐에 좋은 음식' 부아메라' 오일 효능 및 부작용은?…\뉴기니섬 고산지...'"
# 2860                            '슈퍼주니어 규현, ‘SKF 2019’ 출격'
# 2861               '“임신한 채 고문·구타 당한 듯”…시리아 난민촌서 인니 여성 사망'
# 2862                                     ' 의열단, 항일의 불꽃 外'
# 2863                     '“파월이 또 우릴 실망시켰다”‥트럼프 맹비난(종합2보)'
# 2864                   '해외무대서 기술 뽐내는 中企… '세계 최초' 제품에 러브콜'
# 2865                    '10년여만에 美 금리인하 물꼬…\우리도 따라 내린다\"'"
# 2866                  '전남테크노파크, 전남 e-모빌리티산업 활성화 기업간담회 개최'
# 2867                        ' RF 온라인, 12년만에 인도네시아 서비스 종료'
# 2868              ' ABCC FINTECH INDONESIA, 양해각서(MOU) 체결'
# 2869                                '옥천 복숭아, 홍콩 시장 공략 나서'
# 2870            '‘애인과 혼전 성관계’ 때문에 어느 20대 여성이 받은 무시무시한 처벌'
# 2871                 '부산대병원 개발 '의료영상저장전송시스템', 카자흐스탄서 맹활약'
# 2872                  'aT 인도네시아서 K-Food 2,235만불 수출상담등 쾌거'
# Name: title, Length: 2873, dtype: object

# %% [markdown]
# ## 3)한글이 아닌 단어 지우기

# %%
#전체제목
# 리스트전체가 아니라 하나씩 빼서 처리해야하기 때문에 for문으로 처리.
#1.한글 및 공백을 제외한 문자를 모두 제거
for i in range(len(title)) :
    title[i] = re.sub("[^가-힣ㄱ-ㅎ ㅏ-ㅣ\\s]","", title[i])

print(title)
# Out:
# ['사진조여정우아한 플라워원피스 입고', '프로필국세청 과장급 전보자월 일 자', '조이춘사영화제 참석한 봉준호 감독한진원 작가', '사진클라라시선 올킬 블루 롱드레스', '사진개부문 노미네이트 기생충 봉준호 감독엄청난 환호 받으며', '사진함소원우아한 입장', '조이엄태구 지적인 남자야', '조이진기주 매력적인 미모', '조이기생충 이정은 엄마 미소', '조이공명 춘사영화제 빛내는 미소', '조이춘사영화제 조여정 칸이 반한 미소', '조이춘사영화제 문지인 민트여신', '사진공명훈남 매력', '무역위 전기프라이팬 특허권 침해 불공정무역행위 조사 개시', '사진베이비페이스 이성경화려한 변신', '사진클라라섹시하게', '사진상체 노출 클라라이보다 더 아찔할 수 없어', '조이조여정 춘사영화제 여우주연상에 빛나는 자태', '조이함소원 연하 남편을 향한 마음', '사진춘사영화제 참석한 기생충 봉준호 감독', '사진이정은영화 팬 여러분 사랑해요', '사진문지인섹시 레드립', '사진하지영어느덧 여배우', '사진김강현춘사영화제 왔어요', '사진공명달콤한 하트', '조이전여빈 우아한 블랙 드레스', '조이전여빈 춘사영화제가 주목하는 신예', '사진공명젠틀하게', '조이문지인 년차 베테랑 여배우', '사진전여빈아름다운 미소', '조이춘사영화제 이성경 금빛 몸매', '조이클라라 보기만 해도 시원한 블루 드레스', '사진정애연단아한 매력', '사진정애연춘사영화제 
', '부산 다대포송정사하 서핑스팟에서 즐기는 짜릿한 서핑 서프버디 그', ' 치킨프랜차이즈 닭껍데기 열풍에 합류', ' 몰고 빈탄섬 질주해보세요', '비치발리볼 화보 거기서 뭐 하세요', '비치발리볼 화보 받아라 강스파이크', '데뷔 년 월 히트곡 뚜두뚜두 뮤직비디오가 팝', '인도네시아어 년 월 일 오늘의 외국어 한마디는', '해외 매체들 방탄소년단 뷔 배려와 가족 사랑의 아이콘 극찬', '뚜두뚜두 이들은 지난해 월 서울을 시작으로', '오늘의 채널유권 손님맞이 나서자 팬미팅 방불', '알맹이는 가라 닭껍질부터 귤껍질까지 껍데기 전성시대', '뚜두뚜두 블랙핑크  ...

# %% [markdown]
# # 2. 형태소 나누기

# %%
from konlpy.tag import Okt

# %%
#전체 형태소나누기
#불용어 제거하기 위해 문장 단어 나누기
okt=Okt() 
title_text=[ ] # or title_text=[''] * len(title)
for i in range(len(title)) :
    title_text.append(okt.morphs(title[i],stem=True))

print(title_text[:10])
# Out:
# C:\Users\glass\Anaconda3\lib\site-packages\jpype\_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)
# [['사진', '조여정', '우아하다', '플라워', '원피스', '입다'], ['프로필', '국세청', '과장', '급', '전보', '자월', '일', '자'], ['조', '이춘사', '영화제', '참석', '한', '봉준호', '감독', '한', '진원', '작가'], ['사진', '클라라', '시선', '올킬', '블루', '롱', '드레스'], ['사진', '개', '부문', '노미네이트', '기생충', '봉준호', '감독', '엄청나다', '환호', '받다'], ['사진', '함소원', '우아하다', '입장'], ['조이', '엄태구', '지적', '인', '남자', '야'], ['조이진', '기주', '매력', '적', '인', '미모'], ['조이', '기생충', '이정은', '엄마', '미소'], ['조이', '공명', '추다', '영화제', '빛', '내다', '미소']]

# %% [markdown]
# ## 4) 단어 분포도(Word Distribution)

# %%
# 명사만 뽑기

def tokenize(doc):
    return okt.nouns(doc)

# %%
sentences_new = [tokenize(d) for d in title]

# %%
print(sentences_new[:10])
# Out:
# [['사진', '조여정', '플라워', '원피스'], ['프로필', '국세청', '과장', '전보', '자월', '일', '자'], ['이춘사', '영화제', '참석', '봉준호', '감독', '진원', '작가'], ['사진', '클라라', '시선', '올킬', '블루', '롱', '드레스'], ['사진', '부문', '노미네이트', '기생충', '봉준호', '감독', '환호'], ['사진', '함소원', '입장'], ['조이', '엄태구', '지적', '남자'], ['조이진', '기주', '매력', '미모'], ['조이', '기생충', '이정은', '엄마', '미소'], ['조이', '공명', '영화제', '빛', '미소']]

# %%
tokens = [j for i in sentences_new for j in i]

# %%
tokens[:10]
# Out:
# ['사진', '조여정', '플라워', '원피스', '프로필', '국세청', '과장', '전보', '자월', '일']

# %%
tokens # stop words에 쓰기
# Out:
# ['사진',
#  '조여정',
#  '플라워',
#  '원피스',
#  '프로필',
#  '국세청',
#  '과장',
#  '전보',
#  '자월',
#  '일',
#  '자',
#  '이춘사',
#  '영화제',
#  '참석',
#  '봉준호',
#  '감독',
#  '진원',
#  '작가',
#  '사진',
#  '클라라',
#  '시선',
#  '올킬',
#  '블루',
#  '롱',
#  '드레스',
#  '사진',
#  '부문',
#  '노미네이트',
#  '기생충',
#  '봉준호',
#  '감독',
#  '환호',
#  '사진',
#  '함소원',
#  '입장',
#  '조이',
#  '엄태구',
#  '지적',
#  '남자',
#  '조이진',
#  '기주',
#  '매력',
#  '미모',
#  '조이',
#  '기생충',
#  '이정은',
#  '엄마',
#  '미소',
#  '조이',
#  '공명',
#  '영화제',
#  '빛',
#  '미소',
#  '이춘사',
#  '영화제',
#  '조여정',
#  '칸',
#  '반한',
#  '미소',
#  '이춘사',
#  '영화제',
#  '문지',
#  '민트',
#  '여신',
#  '사진',
#  '공명',
#  '훈남',
#  '매력',
#  '무역',
#  '위',
#  '전기',
#  '프라이팬',
#  '특허권',
#  '침해',
#  '불공정',
#  '무역',
#  '행위',
#  '조사',
#  '개시',
#  '사진',
#  '베이비페이스',
#  '이성경',
#  '변신',
#  '사진',
#  '클라라',
#  '사진',
#  '상체',
#  '노출',
#  '클라라',
#  '더',
#  '수',
#  '조이조',
#  '여정',
#  '영화제',
#  '여우주연상',
#  '자태',
#  '조이',
#  '함소원',
#  '연하',
#  '남편',
#  '향',
#  '마음',
#  '사진',
#  '영화제',
#  '참석',
#  '기생충',
#  '봉준호',
#  '감독',
#  '사진',
#  '이정은',
#  '영화',
#  '팬',
#  '여러분',
#  '사랑',
#  '사진',
#  '지인',
#  '섹시',
#  '레드',
#  '립',
#  '사진',
#  '하지영',
#  '여배우',
#  '사진',
#  '김강현',
#  '영화제',
#  '진공',
#  '하트',
#  '이전',
#  '빈',
#  '블랙',
#  '드레스',
#  '이전',
#  '빈',
#  '영화제',
#  '주목',
#  '신예',
#  '진공',
#  '젠틀',
#  '조이',
#  '지인',
#  '년차',
#  '베테',
#  '여배우',
#  '사진전',
#  '빈',
#  '미소',
#  '이춘사',
#  '영화제',
#  '이성경',
#  '금빛',
#  '몸매',
#  '조이',
#  '클라라',
#  '보기',
#  '해도',
#  '블루',
#  '드레스',
#  '사진',
#  '정애연',
#  '단아',
#  '매력',
#  '사진',
#  '정애연',
#  '영화제',
#  '레드카펫',
#  '사진',
#  '주지훈',
#  '그',
#  '시그널',
#  '사진',
#  '주지훈',
#  '럭셔리',
#  '사진',
#  '주지훈',
#  '오늘',
#  '폭발',
#  '사진',
#  '기생충',
#  '박명',
#  '훈춘',
#  '영화제',
#  '수상',
#  '사진',
#  '진원',
#  '작가',
#  '봉준호',
#  '감독',
#  '기생충',
#  '초대',
#  '사진',
#  '골드',
#  '드레스',
#  '이성경',
#  '귀걸이',
#  '금빛',
#  '하트',
#  '사진',
#  '레드카펫',
#  '런웨이',
#  '이성경',
#  '모델',
#  '달라',
#  '달라',
#  '사진',
#  '이성경',
#  '금빛',
#  '각선미',
#  '사진',
#  '조여정',
#  '미모',
#  '사진',
#  '조여정',
#  '아기',
#  '미소',
#  '사진',
#  '조여정',
#  '미소',
#  '여신',
#  '사진',
#  '꽃',
#  '더',
#  '조여정',
#  '미모',
#  '사진',
#  '미소',
#  '조여정',
#  '중기',
#  '해외진출',
#  '지원',
#  '발',
#  '나선',
#  '부산',
#  '경진',
#  '창조',
#  '혁신',
#  '센터',
#  '오',
#  '명불허전',
#  '클라라',
#  '명품',
#  '콜라',
#  '병',
#  '몸매',
#  '시선집중',
#  '공사',
#  '첨단',
#  '환경기술',
#  '눈',
#  '도장',
#  '경영',
#  '대표팀',
#  '메인',
#  '풀',
#  '첫',
#  '훈련',
#  '메달',
#  '김서영',
#  '컨디션',
#  '이상',
#  '무',
#  '김주희',
#  '무용가',
#  '두리안',
#  '먹방',
#  '채',
#  '매력',
#  '캄보디아',
#  '여행',
#  '경북',
#  '중소기업',
#  '수출',
#  '지원',
#  '러시아',
#  '인니',
#  '교두보',
#  '이철우',
#  '경북',
#  '도지사',
#  '산다',
#  '도정',
#  '국제',
#  '경쟁력',
#  '강화',
#  '바람',
#  '방송',
#  '세계',
#  '테마',
#  '기행',
#  '여름날',
#  '꿈',
#  '캄보디아',
#  '부',
#  '바다',
#  '세계',
#  '테마',
#  '기행',
#  '캄폿',
#  '코롱',
#  '산',
#  '로엠',
#  '프놈펜',
#  '김주희',
#  '굿바이',
#  '캄',
#  '수출',
#  '규제',
#  '악재',
#  '남방',
#  '시장',
#  '돌파구',
#  '접',
#  '인도네시아',
#  '토라',
#  '페스티벌',
#  '초청',
#  '공연',
#  '세계',
#  '테마',
#  '기행',
#  '무용가',
#  '김주희',
#  '캄보디아',
#  '바다',
#  '여정',
#  '인도네시아어',
#  '년',
#  '월',
#  '일',
#  '오늘',
#  '외국어',
#  '한마디',
#  '이',
#  '시각',
#  '세계',
#  '기내식',
#  '메뉴판',
#  '잘못',
#  '감옥',
#  '행',
#  '위기',
#  '최초',
#  '제안',
#  '가점',
#  '확대',
#  '민간',
#  '제안',
#  '활성화',
#  '전은영',
#  '글로벌',
#  '아트',
#  '홀',
#  '대표이사',
#  '진범',
#  '구성',
#  '긴장감',
#  '스토리',
#  '신봉선',
#  '공개',
#  '사진',
#  '속',
#  '신봉선',
#  '김',
#  '역사',
#  '속',
#  '오늘',
#  '월',
#  '일',
#  '임오군란',
#  '발생',
#  '공사',
#  '한국',
#  '필',
#  '환경',
#  '기술',
#  '인도네시아',
#  '호평',
#  '대구',
#  '경북',
#  '블루',
#  '오션',
#  '할랄',
#  '시장',
#  '재',
#  '조준',
#  '이정현',
#  '득점',
#  '한국',
#  '존스',
#  '컵',
#  '캐나다',
#  '대파',
#  '인니',
#  '대사관',
#  '임무',
#  '관',
#  '남한',
#  '면적',
#  '배',
#  '산림',
#  '정신',
#  '건강',
#  '우리',
#  '산림청',
#  '해외',
#  '산림',
#  '탄소배출권',
#  '사업',
#  '소개',
#  '보잉',
#  '맥스',
#  '운항',
#  '금지',
#  '분기',
#  '조천억원',
#  '타격',
#  '유종',
#  '산림',
#  '윤영균',
#  '산림',
#  '복지',
#  '진흥',
#  '원장',
#  '명',
#  '리학',
#  '세상',
#  '재벌',
#  '게',
#  '숙제',
#  '사람',
#  '아스',
#  '트',
#  '과',
#  '엠브라에르',
#  '수주',
#  '계약',
#  '체결',
#  '실적',
#  '증진',
#  '기대',
#  '푸드',
#  '중국',
#  '철수',
#  '대신',
#  '뚜레쥬르',
#  '힘',
#  '이유',
#  '커피',
#  '만화경',
#  '커피',
#  '평화',
#  '인니',
#  '기내식',
#  '손글씨',
#  '메뉴판',
#  '논란',
#  '사진',
#  '승객',
#  '명예훼손',
#  '피소',
#  '뉴스',
#  '아기',
#  '상어',
#  '뚜',
#  '루루',
#  '뚜루',
#  '동요',
#  '노숙자',
#  '부산시',
#  '인도네시아',
#  '산업',
#  '계전',
#  '참가',
#  '기업',
#  '모집',
#  '발간',
#  '단열',
#  '한희준',
#  '대표',
#  '물욕',
#  '가치',
#  '기업가',
#  '정신',
#  '개인주의',
#  '집단',
#  '주의',
#  '뭐',
#  '더',
#  '장단점',
#  '세아',
#  '친환경',
#  '비즈니스',
#  '도입',
#  '통한',
#  '혁신',
#  '시너지',
#  '기대',
#  '가루다',
#  '항공',
#  '손글씨',
#  '메뉴',
#  '승객',
#  '명예훼손',
#  '혐의',
#  '피소',
#  '가루다',
#  '항공',
#  '손글씨',
#  '메뉴',
#  '승객',
#  '명예훼손',
#  '피소',
#  '작업복',
#  '외길',
#  '년',
#  '토피아',
#  '티뷰',
#  '통해',
#  '꼭',
#  '곳',
#  '반드시',
#  '광주',
#  '계수영',
#  '김서영',
#  '오',
#  '투병',
#  '중인',
#  '이케',
#  '위',
#  '연예인',
#  '다이어트',
#  '홍지민',
#  '다이어트',
#  '비법',
#  '핑거루트',
#  '핑거',
#  '루트',
#  '아시아',
#  '짐',
#  '카나',
#  '대회',
#  '월말',
#  '인제스피디움',
#  '개최',
#  '다니엘',
#  '도회',
#  '협력',
#  '교회',
#  '목사',
#  '간담',
#  '회',
#  '두산',
#  '서비스',
#  '경진',
#  '대회',
#  '아야',
#  '귀국',
#  '인도네시아',
#  '유권',
#  '손짓',
#  '번',
#  '팝업',
#  '스토어',
#  '아야',
#  '귀국',
#  '인도',
#  '현지',
#  '쇼호',
#  '스트로',
#  '변신',
#  '신봉선',
#  '성공',
#  '먹방',
#  '가루다',
#  '항공',
#  '손글씨',
#  '메뉴',
#  '승객',
#  '방',
#  '끝내',
#  '종합',
#  '자동차경주',
#  '협회',
#  '인제스피디움',
#  '아시아',
#  '오토',
#  '짐',
#  '카나',
#  '대회',
#  '라운드',
#  '보잉',
#  '맥스',
#  '운항',
#  '중단',
#  '분기',
#  '조억',
#  '부담',
#  '세아',
#  '역',
#  '세아',
#  '테크',
#  '친환경',
#  '정책',
#  '협력',
#  '보잉',
#  '맥스',
#  '운항',
#  '금지',
#  '조천억원',
#  '타격',
#  '보잉',
#  '맥스',
#  '운항',
#  '중단',
#  '조억원',
#  '손실',
#  '보잉',
#  '맥스',
#  '운항',
#  '금지',
#  '분기',
#  '조억원',
#  '타격',
#  '아야',
#  '귀국',
#  '인도네시아',
#  '줄',
#  '시오',
#  '메뉴',
#  '손님',
#  '업그레이드',
#  '세계',
#  '대학',
#  '장단',
#  '건양대',
#  '병원',
#  '방문',
#  '빈탄',
#  '섬',
#  '세계',
#  '골프장',
#  '잔디',
#  '디너',
#  '인도네시아',
#  '빈탄',
#  '섬',
#  '북부',
#  '해변',
#  '오아시스',
#  '클럽메드',
#  '인도네시아',
#  '빈탄',
#  '섬',
#  '해변',
#  '풀',
#  '빌라',
#  '빈탄',
#  '대자연',
#  '품',
#  '힐링',
#  '휴가',
#  '더',
#  '레지던스',
#  '빈탄',
#  '아이',
#  '천국',
#  '키즈',
#  '클럽',
#  '경기',
#  '바로미터',
#  '구리',
#  '가격',
#  '더',
#  '수요',
#  '아야',
#  '귀국',
#  '인도네시아',
#  '신봉선',
#  '말',
#  '빵',
#  '빵',
#  '현지',
#  '홈쇼핑',
#  '무슨',
#  '더',
#  '레지던스',
#  '빈탄',
#  '나',
#  '전용',
#  '수영장',
#  '조식',
#  '빈탄',
#  '청정',
#  '바다',
#  '패',
#  '보드',
#  '타',
#  '첫방송',
#  '매진',
#  '포레스트',
#  '힐',
#  '그린',
#  '밸런스',
#  '클렌져',
#  '앵콜',
#  '방송',
#  '확정',
#  '본느',
#  '포레스트',
#  '힐',
#  '그린',
#  '밸런스',
#  '클렌져',
#  '일',
#  '쇼핑',
#  '앵콜',
#  '방송',
#  '김복동',
#  '할머니',
#  '평화',
#  '공원',
#  '양산',
#  '아야',
#  '귀국',
#  '인도네시아',
#  '신봉선',
#  '본격',
#  '영업',
#  '시작',
#  '홍보',
#  '도전',
#  '물리',
#  '발리',
#  '트래블',
#  '레져',
#  '선정',
#  '관왕',
#  '수상',
#  '한국',
#  '지능',
#  '교통',
#  '시스템',
#  '아세안',
#  '시장',
#  '진출',
#  '타진',
#  '실트',
#  '황제',
#  '방탄소년단',
#  '지민',
#  '위엄',
#  '숨',
#  '실시간',
#  '트렌드',
#  '점령',
#  '화제',
#  '클럽메드',
#  '빈탄',
#  '골프',
#  '입문',
#  '더',
#  '레지던스',
#  '빈탄',
#  '자랑',
#  '스파',
#  '더',
#  '레지던스',
#  '빈탄',
#  '더',
#  '다이닝',
#  '룸',
#  '팝아티스트',
#  '낸시랭',
#  '글로벌',
#  '아트',
#  '페어',
#  '싱가포르',
#  '스칼렛',
#  '맛집',
#  '기준',
#  '감자탕',
#  '이정열',
#  '대표',
#  '맛집',
#  '철학',
#  '이야기',
#  '바다',
#  '경치',
#  '힐링',
#  '클럽메드',
#  '빈탄',
#  '아일랜드',
#  '스파',
#  '온갖',
#  '액',
#  '티비',
#  '티',
#  '천국',
#  '클럽메드',
#  '빈탄',
#  '아일랜드',
#  '클럽메드',
#  '볼',
#  '수',
#  '것',
#  '쇼',
#  '더',
#  '레지던스',
#  '빈탄',
#  '스페셜',
#  '티',
#  '레스토랑',
#  '리차',
#  '리차',
#  '인도네시아',
#  '미식',
#  '내',
#  '맛',
#  '배',
#  '아야',
#  '귀국',
#  '블락비',
#  '유권',
#  '손짓',
#  '번',
#  '팝업',
#  '스토어',
#  '이승현',
#  '점한국',
#  '존스',
#  '컵',
#  '국제',
#  '농구',
#  '일본',
#  '제압',
#  '지역',
#  '산업',
#  '지지',
#  '동남아시아',
#  '시장',
#  '진출',
#  '인도네시아',
#  '년',
#  '전기차',
#  '생산',
#  '시작',
#  '토요타',
#  '현대차',
#  '관심',
#  '블랙',
#  '핑크',
#  '제니',
#  '숲속',
#  '공주',
#  '인형',
#  '비주',
#  '얼',
#  '방탄소년단',
#  '뷔',
#  '배려',
#  '가족',
#  '사랑',
#  '아이콘',
#  '해외',
#  '매체',
#  '극찬',
#  '역시',
#  '굿',
#  '보이',
#  '쉘',
#  '그룹',
#  '제로',
#  '공급',
#  '부산',
#  '다대',
#  '포',
#  '송정',
#  '사하',
#  '서핑',
#  '스팟',
#  '서핑',
#  '프',
#  '버디',
#  '그',
#  '치킨',
#  '프랜차이즈',
#  '닭',
#  '껍데기',
#  '열풍',
#  '합류',
#  '빈탄',
#  '섬',
#  '질주',
#  '비치발리볼',
#  '화보',
#  '거기',
#  '뭐',
#  '비치발리볼',
#  '화보',
#  '강',
#  '스파이크',
#  '데뷔',
#  '년',
#  '월',
#  '히트',
#  '곡',
#  '뚜',
#  '뚜',
#  '뮤직비디오',
#  '팝',
#  '인도네시아어',
#  '년',
#  '월',
#  '일',
#  '오늘',
#  '외국어',
#  '한마디',
#  '해외',
#  '매체',
#  '방탄소년단',
#  '뷔',
#  '배려',
#  '가족',
#  '사랑',
#  '아이콘',
#  '극찬',
#  '뚜',
#  '뚜',
#  '이',
#  '지난해',
#  '월',
#  '서울',
#  '시작',
#  '오늘',
#  '채널',
#  '유권',
#  '손님',
#  '맞이',
#  '팬미팅',
#  '방불',
#  '알맹이',
#  '가라',
#  '닭',
#  '껍질',
#  '귤',
#  '껍질',
#  '껍데기',
#  '전성',
#  '시대',
#  '뚜',
#  '뚜',
#  '블랙',
#  '핑크',
#  '월드',
#  '투어',
#  '전',
#  '세계',
#  '아야',
#  '귀국',
#  '멤버',
#  '인도네시아',
#  '현지',
#  '홈쇼핑',
#  '쇼',
#  '호스트',
#  '변신',
#  '인니',
#  '코모',
#  '섬',
#  '내년',
#  '최소',
#  '년',
#  '폐쇄',
#  '멸종',
#  '막',
#  '것',
#  '진범',
#  '회',
#  '부천',
#  '국제',
#  '판타스틱',
#  '영화제',
#  '국제',
#  '경쟁',
#  '부문',
#  '부천',
#  '인니',
#  '방영',
#  '만화',
#  '국산',
#  '오승현',
#  '애니',
#  '감독',
#  '깃발',
#  '정승환',
#  '어스',
#  '그래픽',
#  '모티브',
#  '아야',
#  '귀국',
#  '인도네시아',
#  ...]

# %%
# nouns = pd.DataFrame(tokens)
# nouns.to_csv('allnouns.csv')

# %%
pd

# %%
# 폰트경로:'C:/Users/glass/Downloads/gulim.ttc'
#C:/Users/glass/Anaconda3/Lib/site-packages/jupyterthemes/fonts/gulim.ttc

# %%
tokens = [j for i in sentences_new for j in i]


import nltk

text = nltk.Text(tokens) 


import matplotlib.pyplot as plt
from matplotlib import font_manager, rc 

font_fname = 'C:/Users/glass/Downloads/gulim.ttc'     # A font of your choice
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)


fig = plt.figure()
fig.set_label('test')
plt.figure(figsize=(20, 10)) 
text.plot(50)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-76b2bcc771f7> in <module>
#      11
#      12 font_fname = 'C:/Users/glass/Downloads/gulim.ttc'     # A font of your choice
# ---> 13 font_name = font_manager.FontProperties(fname=font_fname).get_name()
#      14 rc('font', family=font_name)
#      15
#
# ~\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_name(self)
#     684         Return the name of the font that best matches the font properties.
#     685         """
# --> 686         return get_font(findfont(self)).family_name
#     687
#     688     def get_style(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1339     if hinting_factor is None:
#    1340         hinting_factor = rcParams['text.hinting_factor']
# -> 1341     return _get_font(filename, hinting_factor)
#    1342
#    1343
#
# RuntimeError: In FT2Font: Can not load face.  Unknown file format.

# %%
fig = plt.figure()
fig.set_label('test')
plt.figure(figsize=(20, 10)) 
text.plot(50)
# Out:
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45348 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48268 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45768 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54644 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50948 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48712 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53444 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49905 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47476 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52395 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45720 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47784 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52280 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47589 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51081 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45236 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45348 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48268 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45768 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 51068 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50556 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44480 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54644 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 50948 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48712 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 53444 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 45380 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 50900 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49905 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47476 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 52395 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 53440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 53944 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45720 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44508 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47784 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 47749 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52280 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 54924 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:176: RuntimeWarning: Glyph 46321 missing from current font.
#   font.load_char(ord(s), flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52852 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 47589 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 51081 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 44208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\glass\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 45236 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# wordcloud
#wordcloud
# title(제목) 많이 사용된 단어
from wordcloud import WordCloud
cloud=WordCloud(width=800,height=600,font_path='C:/Users/glass/Downloads/gulim.ttc').generate(" ".join(text))
plt.figure(figsize=(20,15))
plt.imshow(cloud)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# # 3.데이터 전처리 (Data Preprocessing)

# %% [markdown]
# ##  5) 불용어 처리 ( Stop words remove)

# %%
test = []
# stop_words=['우아하다']
for i in range(len(title_text)):
    j = 0
    while(j < len(title_text[i])):
        if(title_text[i][j] in stop_words):
            title_text[i].remove(title_text[i][j])
            continue
        j += 1
    test.append(title_text[i])

print(test)

# %%
# def tokenize_new(doc):
#     x = [line.rstrip('\n') for line in open('C:/Users/DongA2/Final_Final_Disertation/File/new_stop.txt', 'r', encoding='utf-8')]
#     word_tokens = tagger.nouns(doc)
#     result = [] 
    
#     for w in word_tokens: 
#         if w not in x: 
            
#             result.append(w) 
#     return result

# %% [markdown]
# # 4.word2vec 벡터화

# %%
#word2vec 파라미터 설명
# workers =프로세스개수
# size= 워드 벡터 특징값수(벡터의 차원을 정한다.)
# min_count =단어에 대한 최소 빈도수(적은 빈도수의 단어는 학습하지 않는다. )
# window =컨테스트 윈도우 크기
# sample=샘플링 비율 (Ex)1e-3 :0.001이 좋은 성능을 낸다

# %%
#진행상황확인위해
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',level=logging.INFO)

# %%
from gensim.models import Word2Vec
print("Training model...")
model= Word2Vec(title_text, size=300, window=5, min_count=5, workers=4, sg=1)

# %% [markdown]
# # 5.텍스트 유사도

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
train1, test1 = train_test_split(title, test_size=0.2)

# %%
train1.info

# %% [markdown]
# ## 명사만 추가한 리스트 만들기 (extraction only nouns)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from konlpy.tag import Okt

okt=Okt()

doc_nouns_list=[]

for doc in train_title:
    nouns=okt.nouns(doc)
    doc_nouns=''
    
    for noun in nouns:
        doc_nouns+=noun + ' '
    doc_nouns_list.append(doc_nouns)
    
for i in range(0,len(train_title)):
    print('doc' +str(i+1)+ ' : ' +str(doc_nouns_list[i]))

# %% [markdown]
# ## 문장 유사도  (Text Similarity)

# %%
tfidf_vectorizer=TfidfVectorizer(min_df=1)
tfidf_matrix = tfidf_vectorizer.fit_transform(doc_nouns_list)

document_distances=(tfidf_matrix*tfidf_matrix.T)

print('유사도 분석을 위한' + str(document_distances.get_shape()[0])+'x'+str(document_distances.get_shape()[1])+'matrix를 만들었습니다')
print(document_distances.toarray())

# %% [markdown]
# ## 6) 유사도 붙이기

# %% [markdown]
# https://stackoverflow.com/questions/22129943/how-to-calculate-the-sentence-similarity-using-word2vec-model-of-gensim-with-pyt

# %%
# s1_afv = avg_feature_vector('this is a sentence', model=model, num_features=300, index2word_set=index2word_set)
# s2_afv = avg_feature_vector('this is also sentence', model=model, num_features=300, index2word_set=index2word_set)
# sim = 1 - spatial.distance.cosine(s1_afv, s2_afv)
# print(sim)

# > 0.915479828613
